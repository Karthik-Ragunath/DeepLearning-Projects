# %% [markdown]
# <a href="https://colab.research.google.com/github/Karthik-Ragunath/DeepLearning-Projects/blob/master/DDU_Networks.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
import sys

# %%
cd 'drive/MyDrive/DDU'
# Out:
# /content/drive/MyDrive/DDU

# %%
# !wget -c https://repo.continuum.io/archive/Anaconda3-2020.02-Linux-x86_64.sh
# Out:
# --2022-02-19 01:13:34--  https://repo.continuum.io/archive/Anaconda3-2020.02-Linux-x86_64.sh
# Resolving repo.continuum.io (repo.continuum.io)... 104.18.200.79, 104.18.201.79, 2606:4700::6812:c94f, ...
# Connecting to repo.continuum.io (repo.continuum.io)|104.18.200.79|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://repo.anaconda.com/archive/Anaconda3-2020.02-Linux-x86_64.sh [following]
# --2022-02-19 01:13:34--  https://repo.anaconda.com/archive/Anaconda3-2020.02-Linux-x86_64.sh
# Resolving repo.anaconda.com (repo.anaconda.com)... 104.16.130.3, 104.16.131.3, 2606:4700::6810:8303, ...
# Connecting to repo.anaconda.com (repo.anaconda.com)|104.16.130.3|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 546910666 (522M) [application/x-sh]
# Saving to: ‘Anaconda3-2020.02-Linux-x86_64.sh’
#
# Anaconda3-2020.02-L 100%[===================>] 521.57M  17.3MB/s    in 20s
#
# ...

# %%
# !chmod +x Anaconda3-2020.02-Linux-x86_64.sh

# %%
# !bash ./Anaconda3-2020.02-Linux-x86_64.sh -b -f -p /usr/local
# Out:
# PREFIX=/usr/local
# Unpacking payload ...
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - _ipyw_jlab_nb_ext_conf==0.1.0=py37_0
#     - _libgcc_mutex==0.1=main
#     - alabaster==0.7.12=py37_0
#     - anaconda-client==1.7.2=py37_0
#     - anaconda-navigator==1.9.12=py37_0
#     - anaconda-project==0.8.4=py_0
#     - anaconda==2020.02=py37_0
#     - argh==0.26.2=py37_0
#     - asn1crypto==1.3.0=py37_0
#     - astroid==2.3.3=py37_0
#     - astropy==4.0=py37h7b6447c_0
#     - atomicwrites==1.3.0=py37_1
#     - attrs==19.3.0=py_0
#     - autopep8==1.4.4=py_0
#     - babel==2.8.0=py_0
#     - backcall==0.1.0=py37_0
#     - backports.functools_lru_cache==1.6.1=py_0
#     - backports.shutil_get_terminal_size==1.0.0=py37_2
#     - backports.tempfile==1.0=py_1
#     - backports.weakref==1.0.post1=py_1
#     - backports==1.0=py_2
#     - beautifulsoup4==4.8.2=py37_0
#     - bitarray==1.2.1=py37h7b6447c_0
# ...

# %%
sys.path.append('/usr/local/lib/python3.8/site-packages')

# %%
# !conda env create -f environment.yml
# Out:
# done
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.8.2
#   latest version: 4.11.0
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# ...
# sniffio-1.2.0        | 15 KB     | : 100% 1.0/1 [00:00<00:00,  8.65it/s]
# six-1.16.0           | 18 KB     | : 100% 1.0/1 [00:00<00:00,  5.07it/s]
# jupyter_server-1.13. | 259 KB    | : 100% 1.0/1 [00:00<00:00,  7.04it/s]
# nest-asyncio-1.5.4   | 9 KB      | : 100% 1.0/1 [00:00<00:00, 25.73it/s]
# xorg-libxrender-0.9. | 32 KB     | : 100% 1.0/1 [00:00<00:00, 24.13it/s]
# google-auth-oauthlib | 19 KB     | : 100% 1.0/1 [00:00<00:00, 17.97it/s]
# entrypoints-0.4      | 9 KB      | : 100% 1.0/1 [00:00<00:00, 24.61it/s]
# networkx-2.6.3       | 1.5 MB    | : 100% 1.0/1 [00:00<00:00,  2.97it/s]
# giflib-5.2.1         | 82 KB     | : 100% 1.0/1 [00:00<00:00,  8.71it/s]
# _libgcc_mutex-0.1    | 3 KB      | : 100% 1.0/1 [00:00<00:00, 10.81it/s]
# ...

# %%
# !conda update conda -y -q
# !source /usr/local/etc/profile.d/conda.sh
# !conda init 
# !conda install -n root _license -y -q
# Out:
# ...
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - conda
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     backports.functools_lru_cache-1.6.4|     pyhd3eb1b0_0           9 KB
#     backports.tempfile-1.0     |     pyhd3eb1b0_1          11 KB
#     conda-4.11.0               |   py37h06a4308_0        14.4 MB
#     conda-package-handling-1.7.3|   py37h27cfd23_1         881 KB
#     xmltodict-0.12.0           |     pyhd3eb1b0_0          13 KB
#     ------------------------------------------------------------
#                                            Total:        15.3 MB
#
# The following packages will be UPDATED:
#
#   backports.functoo~                             1.6.1-py_0 --> 1.6.4-pyhd3eb1b0_0
#   conda                                        4.8.2-py37_0 --> 4.11.0-py37h06a4308_0
# ...

# %%
# !source activate semantic_scene_understanding

# %%
# !conda info --envs
# Out:
# # conda environments:
# #
# base                  *  /usr/local
# environment              /usr/local/envs/environment
# semantic_scene_understanding     /usr/local/envs/semantic_scene_understanding

# %%
# !pip install prefetch_generator
# Out:
# ...
#   Created wheel for prefetch-generator: filename=prefetch_generator-1.0.1-py3-none-any.whl size=3962 sha256=a9abe9cc0d0c4d6de8171f94226efb87a5901562eff4de998e06342e1dca1381
#   Stored in directory: /root/.cache/pip/wheels/b0/74/c0/b1e681a9b923c953cb89ef3e9bb21c32b3226b50a6911c7080
# Successfully built prefetch-generator
# ...

# %%
# !source activate semantic_scene_understanding && python train.py --seed 1 --dataset cifar10 --dataset-root cifar-10-batches-py --model wide_resnet -sn -mod --coeff 3.0
# Out:
# Namespace(coeff=3.0, data_aug=True, dataset='cifar10', dataset_root='cifar-10-batches-py', epoch=1, first_milestone=150, gpu=True, learning_rate=0.1, log_interval=50, loss_function='cross_entropy', loss_mean=False, mod=True, model='wide_resnet', momentum=0.9, nesterov=False, optimiser='sgd', save_interval=25, save_loc='./', saved_model_name='resnet50_350.model', second_milestone=250, seed=1, sn=True, test_batch_size=128, train_batch_size=128, weight_decay=0.0005)
# Parsed args Namespace(coeff=3.0, data_aug=True, dataset='cifar10', dataset_root='cifar-10-batches-py', epoch=1, first_milestone=150, gpu=True, learning_rate=0.1, log_interval=50, loss_function='cross_entropy', loss_mean=False, mod=True, model='wide_resnet', momentum=0.9, nesterov=False, optimiser='sgd', save_interval=25, save_loc='./', saved_model_name='resnet50_350.model', second_milestone=250, seed=1, sn=True, test_batch_size=128, train_batch_size=128, weight_decay=0.0005)
# Seed:  1
# CUDA set: True
# ...

# %%
# !ls
# Out:
# active_learning_script.py	    README.md
# amnist				    resnet18_1_10.model
# Anaconda3-2020.02-Linux-x86_64.sh   resnet18_1_1.model
# cifar-10-batches-py		    resnet18_1_5.model
# cifar-10-python.tar.gz		    resnet18_1_train_loss.json
# data				    saved_models
# ddu_dirty_mnist-data-v0.6.0	    saved_models_cifar
# ddu_dirty_mnist-data-v0.6.0.tar.gz  stats_logging
# environment.yml			    train_ensemble.py
# evaluate.py			    train.py
# LICENSE				    utils
# metrics				    vis
# net				    wide_resnet_sn_3.0_mod_1_1.model
# notebooks			    wide_resnet_sn_3.0_mod_1_train_loss.json

# %%
# !cp wide_resnet_sn_3.0_mod_1_1.model saved_models_wide_resnet/

# %%
# !source activate semantic_scene_understanding && conda install -c conda-forge tqdm
# Out:
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local/envs/semantic_scene_understanding
#
#   added / updated specs:
#     - tqdm
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ca-certificates-2021.10.8  |       ha878542_0         139 KB  conda-forge
#     certifi-2021.10.8          |   py38h578d9bd_1         145 KB  conda-forge
#     colorama-0.4.4             |     pyh9f0ad1d_0          18 KB  conda-forge
#     tqdm-4.62.3                |     pyhd8ed1ab_0          80 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         381 KB
#
# The following NEW packages will be INSTALLED:
#
#   colorama           conda-forge/noarch::colorama-0.4.4-pyh9f0ad1d_0
#   tqdm               conda-forge/noarch::tqdm-4.62.3-pyhd8ed1ab_0
#
# The following packages will be UPDATED:
#
# ...

# %%
# !source activate semantic_scene_understanding && python evaluate.py --seed 1 --dataset cifar10 --ood_dataset svhn --load-path saved_models_wide_resnet/ --model wide_resnet --runs 1 -sn -mod --coeff 3.0 --model-type softmax
# Out:
# Namespace(batch_size=128, coeff=3.0, data_aug=False, dataset='cifar10', ensemble=5, gpu=True, load_loc='saved_models_wide_resnet/', mod=True, model='wide_resnet', model_type='softmax', ood_dataset='svhn', runs=1, seed=1, sn=True)
# Parsed args Namespace(batch_size=128, coeff=3.0, data_aug=False, dataset='cifar10', ensemble=5, gpu=True, load_loc='saved_models_wide_resnet/', mod=True, model='wide_resnet', model_type='softmax', ood_dataset='svhn', runs=1, seed=1, sn=True)
# Seed:  1
# Files already downloaded and verified
# /usr/local/envs/semantic_scene_understanding/lib/python3.8/site-packages/torch/utils/data/dataloader.py:478: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
# ...

# %%
# !mkdir saved_models_wide_resnet/Run1

# %%
# !cp saved_models_wide_resnet/wide_resnet_sn_3.0_mod_1_1.model saved_models_wide_resnet/Run1/

# %%
# !source activate semantic_scene_understanding && python evaluate.py --seed 1 --dataset cifar10 --ood_dataset svhn --load-path saved_models_wide_resnet/ --model wide_resnet --runs 1 -sn -mod --coeff 3.0 --model-type softmax
# Out:
# Namespace(batch_size=128, coeff=3.0, data_aug=False, dataset='cifar10', ensemble=5, gpu=True, load_loc='saved_models_wide_resnet/', mod=True, model='wide_resnet', model_type='softmax', ood_dataset='svhn', runs=1, seed=1, sn=True)
# Parsed args Namespace(batch_size=128, coeff=3.0, data_aug=False, dataset='cifar10', ensemble=5, gpu=True, load_loc='saved_models_wide_resnet/', mod=True, model='wide_resnet', model_type='softmax', ood_dataset='svhn', runs=1, seed=1, sn=True)
# Seed:  1
# Files already downloaded and verified
# /usr/local/envs/semantic_scene_understanding/lib/python3.8/site-packages/torch/utils/data/dataloader.py:478: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
# ...
