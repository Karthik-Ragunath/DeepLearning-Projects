# %% [markdown]
# <a href="https://colab.research.google.com/github/Karthik-Ragunath/DeepLearning-Projects/blob/master/NLP_Abstractive_Summarizer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
import sys

# %%
cd 'drive/MyDrive/pytorch_multi_head_selection_re'
# Out:
# /content/drive/MyDrive/pytorch_multi_head_selection_re

# %%
# !ls
# Out:
# Anaconda3-2020.02-Linux-x86_64.sh  multi_head_model_info.txt
# batch_data_info.txt		   pip_requirements.txt
# cuda_exp.ipynb			   raw_data
# data				   README.md
# environment.yml			   requirements_copy.txt
# experiments			   requirements.txt
# forward_info.txt		   sample_preprocessing_output.txt
# lib				   saved_models
# main.py

# %%
# %%bash
# # source activate myenv
#
# python
# import sys
# # some simple python commands
# sys.path.append('/usr/local/lib/python3.8/site-packages')
# print(sys.path)
#
# print("Python version")
# print(sys.version)
# Out:
# ['', '/env/python', '/usr/local/lib/python37.zip', '/usr/local/lib/python3.7', '/usr/local/lib/python3.7/lib-dynload', '/usr/local/lib/python3.7/site-packages', '/usr/local/lib/python3.8/site-packages']
# Python version
# 3.7.6 (default, Jan  8 2020, 19:59:22)
# [GCC 7.3.0]

# %%
# !wget -c https://repo.continuum.io/archive/Anaconda3-2020.02-Linux-x86_64.sh
# Out:
# --2022-02-01 09:39:33--  https://repo.continuum.io/archive/Anaconda3-2020.02-Linux-x86_64.sh
# Resolving repo.continuum.io (repo.continuum.io)... 104.18.200.79, 104.18.201.79, 2606:4700::6812:c84f, ...
# Connecting to repo.continuum.io (repo.continuum.io)|104.18.200.79|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://repo.anaconda.com/archive/Anaconda3-2020.02-Linux-x86_64.sh [following]
# --2022-02-01 09:39:34--  https://repo.anaconda.com/archive/Anaconda3-2020.02-Linux-x86_64.sh
# Resolving repo.anaconda.com (repo.anaconda.com)... 104.16.131.3, 104.16.130.3, 2606:4700::6810:8303, ...
# Connecting to repo.anaconda.com (repo.anaconda.com)|104.16.131.3|:443... connected.
# HTTP request sent, awaiting response... 416 Requested Range Not Satisfiable
#
#     The file is already fully retrieved; nothing to do.

# %%
# !chmod +x Anaconda3-2020.02-Linux-x86_64.sh

# %%
# !bash ./Anaconda3-2020.02-Linux-x86_64.sh -b -f -p /usr/local
# Out:
# PREFIX=/usr/local
# Unpacking payload ...
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - _ipyw_jlab_nb_ext_conf==0.1.0=py37_0
#     - _libgcc_mutex==0.1=main
#     - alabaster==0.7.12=py37_0
#     - anaconda-client==1.7.2=py37_0
#     - anaconda-navigator==1.9.12=py37_0
#     - anaconda-project==0.8.4=py_0
#     - anaconda==2020.02=py37_0
#     - argh==0.26.2=py37_0
#     - asn1crypto==1.3.0=py37_0
#     - astroid==2.3.3=py37_0
#     - astropy==4.0=py37h7b6447c_0
#     - atomicwrites==1.3.0=py37_1
#     - attrs==19.3.0=py_0
#     - autopep8==1.4.4=py_0
#     - babel==2.8.0=py_0
#     - backcall==0.1.0=py37_0
#     - backports.functools_lru_cache==1.6.1=py_0
#     - backports.shutil_get_terminal_size==1.0.0=py37_2
#     - backports.tempfile==1.0=py_1
#     - backports.weakref==1.0.post1=py_1
#     - backports==1.0=py_2
#     - beautifulsoup4==4.8.2=py37_0
#     - bitarray==1.2.1=py37h7b6447c_0
# ...

# %%
sys.path.append('/usr/local/lib/python3.8/site-packages')

# %%
# !conda env create -f environment.yml
# Out:
# done
# done
#
# ...
# pyzmq-19.0.2         | 511 KB    | : 100% 1.0/1 [00:00<00:00,  3.73it/s]
# sqlite-3.36.0        | 990 KB    | : 100% 1.0/1 [00:00<00:00,  2.88it/s]
# nest-asyncio-1.5.4   | 9 KB      | : 100% 1.0/1 [00:00<00:00, 25.29it/s]
# terminado-0.12.1     | 28 KB     | : 100% 1.0/1 [00:00<00:00, 26.60it/s]
# cryptography-36.0.0  | 1.3 MB    | : 100% 1.0/1 [00:00<00:00,  4.45it/s]
# ipython-7.18.1       | 1.1 MB    | : 100% 1.0/1 [00:00<00:00,  2.95it/s]
# pyparsing-3.0.6      | 79 KB     | : 100% 1.0/1 [00:00<00:00, 19.35it/s]
# pyrsistent-0.18.0    | 94 KB     | : 100% 1.0/1 [00:00<00:00,  7.02it/s]
# freetype-2.11.0      | 618 KB    | : 100% 1.0/1 [00:00<00:00,  5.40it/s]
# mkl-2021.4.0         | 142.6 MB  | : 100% 1.0/1 [00:05<00:00,  5.82s/it]
# jpeg-9d              | 232 KB    | : 100% 1.0/1 [00:00<00:00,  4.31it/s]
# libgomp-9.3.0        | 311 KB    | : 100% 1.0/1 [00:00<00:00,  6.26it/s]
# prompt-toolkit-3.0.8 | 244 KB    | : 100% 1.0/1 [00:00<00:00,  8.84it/s]
# ...

# %%
# !conda update conda -y -q
# !source /usr/local/etc/profile.d/conda.sh
# !conda init 
# !conda install -n root _license -y -q
# Out:
# ...
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - conda
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     backports.functools_lru_cache-1.6.4|     pyhd3eb1b0_0           9 KB
#     backports.tempfile-1.0     |     pyhd3eb1b0_1          11 KB
#     conda-4.11.0               |   py37h06a4308_0        14.4 MB
#     conda-package-handling-1.7.3|   py37h27cfd23_1         881 KB
#     xmltodict-0.12.0           |     pyhd3eb1b0_0          13 KB
#     ------------------------------------------------------------
#                                            Total:        15.3 MB
#
# The following packages will be UPDATED:
#
#   backports.functoo~                             1.6.1-py_0 --> 1.6.4-pyhd3eb1b0_0
#   conda                                        4.8.2-py37_0 --> 4.11.0-py37h06a4308_0
# ...

# %%
# !source activate multi_head_re

# %%
# !ls
# Out:
# Anaconda3-2020.02-Linux-x86_64.sh  main.py
# batch_data_info.txt		   multi_head_model_info.txt
# cuda_exp.ipynb			   raw_data
# data				   README.md
# environment.yml			   requirements_copy.txt
# experiments			   requirements.txt
# forward_info.txt		   sample_preprocessing_output.txt
# lib				   saved_models

# %%
# !conda info --envs
# Out:
# # conda environments:
# #
# base                  *  /usr/local
# multi_head_re            /usr/local/envs/multi_head_re

# %%
# !activate multi_head_re
# !conda info --envs
# Out:
# # conda environments:
# #
# base                  *  /usr/local
# multi_head_re            /usr/local/envs/multi_head_re

# %%
# activate your conda environment
# %%bash
activate multi_head_re
conda info --envs
python

# python commands are ready to run within your environment
import sys
print("Python version")
print (sys.version)
# Out:
# # conda environments:
# #
# base                  *  /usr/local
# multi_head_re            /usr/local/envs/multi_head_re
#
# Python version
# 3.7.6 (default, Jan  8 2020, 19:59:22)
# [GCC 7.3.0]

# %%
# !source activate multi_head_re && conda info --envs && python
# Out:
# # conda environments:
# #
# base                     /usr/local
# multi_head_re         *  /usr/local/envs/multi_head_re

# %%
# !pip install prefetch_generator
# Out:
# ...
#   Created wheel for prefetch-generator: filename=prefetch_generator-1.0.1-py3-none-any.whl size=3962 sha256=d993383272088cac1653bba7fdeba0c7eac5d52d3397d51507c7333fef058e4d
#   Stored in directory: /root/.cache/pip/wheels/b0/74/c0/b1e681a9b923c953cb89ef3e9bb21c32b3226b50a6911c7080
# Successfully built prefetch-generator
# ...

# %%
# !source activate multi_head_re && python main.py --mode train --exp_name conll_bert_re
# Out:
# Traceback (most recent call last):
#   File "main.py", line 18, in <module>
#     from lib.metrics import F1_triplet, F1_ner
#   File "/content/drive/MyDrive/pytorch_multi_head_selection_re/lib/metrics/__init__.py", line 1, in <module>
#     from lib.metrics.F1_score import *
#   File "/content/drive/MyDrive/pytorch_multi_head_selection_re/lib/metrics/F1_score.py", line 3, in <module>
#     from overrides import overrides
# ModuleNotFoundError: No module named 'overrides'

# %%
# !activate multi_head_re && cat pip_requirements.txt | xargs -n 1 pip install
# Out:
# ...
#      |████████████████████████████████| 78 kB 3.2 MB/s
# ...
#      |████████████████████████████████| 86 kB 2.4 MB/s
# ...
#      |████████████████████████████████| 53 kB 1.6 MB/s
# ERROR: pytest-astropy 0.8.0 requires pytest-cov>=2.0, which is not installed.
# ERROR: pytest-astropy 0.8.0 requires pytest-filter-subpackage>=0.1, which is not installed.
# ...
#   Attempting uninstall: attrs
#     Found existing installation: attrs 19.3.0
#     Uninstalling attrs-19.3.0:
#       Successfully uninstalled attrs-19.3.0
# ...
#      |████████████████████████████████| 8.8 MB 5.2 MB/s
# ...
#   Attempting uninstall: Babel
#     Found existing installation: Babel 2.8.0
#     Uninstalling Babel-2.8.0:
#       Successfully uninstalled Babel-2.8.0
# ...
#   Attempting uninstall: backcall
#     Found existing installation: backcall 0.1.0
#     Uninstalling backcall-0.1.0:
#       Successfully uninstalled backcall-0.1.0
# ...
#      |████████████████████████████████| 157 kB 5.3 MB/s
# ...
#   Attempting uninstall: bleach
# ...

# %%
# !activate multi_head_re && python main.py --mode train --exp_name conll_bert_re
# Out:
# /usr/local/lib/python3.7/site-packages/requests/__init__.py:91: RequestsDependencyWarning: urllib3 (1.26.7) or chardet (3.0.4) doesn't match a supported version!
#   RequestsDependencyWarning)
# ...
# GPU Index: 0
# ...
# 100% 433/433 [00:00<00:00, 428737.87B/s]
# 100% 440473133/440473133 [00:10<00:00, 41607906.65B/s]
# 100% 231508/231508 [00:00<00:00, 1516625.51B/s]
# ========================= Train Function =========================
# Num Samples in Train Set: 910
# ...

# %%
# !python main.py --mode evaluation --exp_name conll_bert_re
# Out:
# /usr/local/lib/python3.7/site-packages/requests/__init__.py:91: RequestsDependencyWarning: urllib3 (1.26.7) or chardet (3.0.4) doesn't match a supported version!
#   RequestsDependencyWarning)
# ...
# GPU Index: 0
# ...
#   0% 0/18 [00:00<?, ?it/s]/usr/local/lib/python3.7/site-packages/numpy/core/fromnumeric.py:3162: FutureWarning: The input object of type 'Tensor' is an array-like implementing one of the corresponding protocols (`__array__`, `__array_interface__` or `__array_struct__`); but not a sequence (or 0-D). In the future, this object will be coerced as if it was first converted using `np.array(obj)`. To retain the old behaviour, you have to either modify the type 'Tensor', or assign to an empty array created with `np.empty(correct_shape, dtype=object)`.
#   return asarray(a).ndim
# ...
