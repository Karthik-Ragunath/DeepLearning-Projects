# %%
#! /bin/bash
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# %sh pip install BeautifulSoup4
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Requirement already satisfied: BeautifulSoup4 in /databricks/python3/lib/python3.7/site-packages (4.9.3)
# Requirement already satisfied: soupsieve&gt;1.2 in /databricks/python3/lib/python3.7/site-packages (from BeautifulSoup4) (2.2.1)
# </div>

# %%
# %sh pip install word2number
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Requirement already satisfied: word2number in /databricks/python3/lib/python3.7/site-packages (1.1)
# </div>

# %%
from word2number import w2n
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
import pandas as pd
# candidate_sentences = spark.read.format("csv").load("dbfs:/FileStore/shared_uploads/t_karthik.ragunath@tatadigital.com/qa.csv", delimiter='\t', encoding='utf-8', index_col=0)
candidate_sentences = pd.read_csv("/dbfs/FileStore/shared_uploads/t_karthik.ragunath@tatadigital.com/qa.csv", delimiter='\t', encoding='utf-8', index_col=0)
check_df = pd.read_csv("/dbfs/FileStore/shared_uploads/t_karthik.ragunath@tatadigital.com/data_cleanser.csv",  header=0, delimiter='\t', error_bad_lines=False)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">b&#39;Skipping line 1114: expected 1 fields, saw 2\nSkipping line 2126: expected 1 fields, saw 2\nSkipping line 2296: expected 1 fields, saw 2\nSkipping line 4922: expected 1 fields, saw 2\nSkipping line 9500: expected 1 fields, saw 2\nSkipping line 12578: expected 1 fields, saw 2\nSkipping line 15295: expected 1 fields, saw 2\nSkipping line 18309: expected 1 fields, saw 2\nSkipping line 21193: expected 1 fields, saw 2\nSkipping line 24723: expected 1 fields, saw 2\nSkipping line 35928: expected 1 fields, saw 2\nSkipping line 38161: expected 1 fields, saw 2\nSkipping line 47049: expected 1 fields, saw 2\nSkipping line 51626: expected 1 fields, saw 2\n&#39;
# </div>

# %%
# %sh pip install -U spacy
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Requirement already satisfied: spacy in /databricks/python3/lib/python3.7/site-packages (2.3.5)
# Collecting spacy
#   Using cached spacy-3.0.6-cp37-cp37m-manylinux2014_x86_64.whl (12.8 MB)
# Requirement already satisfied: typing-extensions&lt;4.0.0.0,&gt;=3.7.4 in /databricks/python3/lib/python3.7/site-packages (from spacy) (3.10.0.0)
# Requirement already satisfied: preshed&lt;3.1.0,&gt;=3.0.2 in /databricks/python3/lib/python3.7/site-packages (from spacy) (3.0.5)
# Collecting catalogue&lt;2.1.0,&gt;=2.0.3
#   Using cached catalogue-2.0.4-py3-none-any.whl (16 kB)
# Collecting srsly&lt;3.0.0,&gt;=2.4.1
#   Using cached srsly-2.4.1-cp37-cp37m-manylinux2014_x86_64.whl (456 kB)
# Requirement already satisfied: jinja2 in /databricks/python3/lib/python3.7/site-packages (from spacy) (2.11.3)
# Requirement already satisfied: blis&lt;0.8.0,&gt;=0.4.0 in /databricks/python3/lib/python3.7/site-packages (from spacy) (0.7.4)
# Collecting thinc&lt;8.1.0,&gt;=8.0.3
#   Using cached thinc-8.0.3-cp37-cp37m-manylinux2014_x86_64.whl (1.1 MB)
# Requirement already satisfied: packaging&gt;=20.0 in /databricks/python3/lib/python3.7/site-packages (from spacy) (20.9)
# Requirement already satisfied: pathy&gt;=0.3.5 in /databricks/python3/lib/python3.7/site-packages (from spacy) (0.5.2)
# Requirement already satisfied: cymem&lt;2.1.0,&gt;=2.0.2 in /databricks/python3/lib/python3.7/site-packages (from spacy) (2.0.5)
# Requirement already satisfied: wasabi&lt;1.1.0,&gt;=0.8.1 in /databricks/python3/lib/python3.7/site-packages (from spacy) (0.8.2)
# Requirement already satisfied: numpy&gt;=1.15.0 in /databricks/python3/lib/python3.7/site-packages (from spacy) (1.16.2)
# Requirement already satisfied: setuptools in /databricks/python3/lib/python3.7/site-packages (from spacy) (56.0.0)
# Requirement already satisfied: tqdm&lt;5.0.0,&gt;=4.38.0 in /databricks/python3/lib/python3.7/site-packages (from spacy) (4.60.0)
# Requirement already satisfied: murmurhash&lt;1.1.0,&gt;=0.28.0 in /databricks/python3/lib/python3.7/site-packages (from spacy) (1.0.5)
# Requirement already satisfied: spacy-legacy&lt;3.1.0,&gt;=3.0.4 in /databricks/python3/lib/python3.7/site-packages (from spacy) (3.0.5)
# Requirement already satisfied: typer&lt;0.4.0,&gt;=0.3.0 in /databricks/python3/lib/python3.7/site-packages (from spacy) (0.3.2)
# Requirement already satisfied: pydantic&lt;1.8.0,&gt;=1.7.1 in /databricks/python3/lib/python3.7/site-packages (from spacy) (1.7.3)
# Requirement already satisfied: requests&lt;3.0.0,&gt;=2.13.0 in /databricks/python3/lib/python3.7/site-packages (from spacy) (2.23.0)
# Requirement already satisfied: zipp&gt;=0.5 in /databricks/python3/lib/python3.7/site-packages (from catalogue&lt;2.1.0,&gt;=2.0.3-&gt;spacy) (3.4.1)
# Requirement already satisfied: pyparsing&gt;=2.0.2 in /databricks/python3/lib/python3.7/site-packages (from packaging&gt;=20.0-&gt;spacy) (2.4.6)
# Requirement already satisfied: smart-open&lt;4.0.0,&gt;=2.2.0 in /databricks/python3/lib/python3.7/site-packages (from pathy&gt;=0.3.5-&gt;spacy) (3.0.0)
# Requirement already satisfied: certifi&gt;=2017.4.17 in /databricks/python3/lib/python3.7/site-packages (from requests&lt;3.0.0,&gt;=2.13.0-&gt;spacy) (2020.4.5.2)
# Requirement already satisfied: idna&lt;3,&gt;=2.5 in /databricks/python3/lib/python3.7/site-packages (from requests&lt;3.0.0,&gt;=2.13.0-&gt;spacy) (2.9)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,&lt;1.26,&gt;=1.21.1 in /databricks/python3/lib/python3.7/site-packages (from requests&lt;3.0.0,&gt;=2.13.0-&gt;spacy) (1.25.9)
# Requirement already satisfied: chardet&lt;4,&gt;=3.0.2 in /databricks/python3/lib/python3.7/site-packages (from requests&lt;3.0.0,&gt;=2.13.0-&gt;spacy) (3.0.4)
# Requirement already satisfied: click&lt;7.2.0,&gt;=7.1.1 in /databricks/python3/lib/python3.7/site-packages (from typer&lt;0.4.0,&gt;=0.3.0-&gt;spacy) (7.1.2)
# Requirement already satisfied: MarkupSafe&gt;=0.23 in /databricks/python3/lib/python3.7/site-packages (from jinja2-&gt;spacy) (1.1.1)
# Installing collected packages: catalogue, srsly, thinc, spacy
#   Attempting uninstall: catalogue
#     Found existing installation: catalogue 1.0.0
#     Uninstalling catalogue-1.0.0:
#       Successfully uninstalled catalogue-1.0.0
#   Attempting uninstall: srsly
#     Found existing installation: srsly 1.0.5
#     Uninstalling srsly-1.0.5:
#       Successfully uninstalled srsly-1.0.5
#   Attempting uninstall: thinc
#     Found existing installation: thinc 7.4.5
#     Uninstalling thinc-7.4.5:
#       Successfully uninstalled thinc-7.4.5
#   Attempting uninstall: spacy
#     Found existing installation: spacy 2.3.5
#     Uninstalling spacy-2.3.5:
#       Successfully uninstalled spacy-2.3.5
# ERROR: pip&#39;s dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# en-core-web-sm 2.3.1 requires spacy&lt;2.4.0,&gt;=2.3.0, but you have spacy 3.0.6 which is incompatible.
# Successfully installed catalogue-2.0.4 spacy-3.0.6 srsly-2.4.1 thinc-8.0.3
# </div>

# %%
#%sh pip install --upgrade --force-reinstall spacy==2.3.5
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# %sh pip install -U pip setuptools wheel
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Requirement already satisfied: pip in /databricks/python3/lib/python3.7/site-packages (21.1.1)
# Requirement already satisfied: setuptools in /databricks/python3/lib/python3.7/site-packages (56.0.0)
# Requirement already satisfied: wheel in /databricks/python3/lib/python3.7/site-packages (0.36.2)
# </div>

# %%
# %sh python -m spacy download en_core_web_sm
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Collecting en-core-web-sm==3.0.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.0.0/en_core_web_sm-3.0.0-py3-none-any.whl (13.7 MB)
# Requirement already satisfied: spacy&lt;3.1.0,&gt;=3.0.0 in /databricks/python3/lib/python3.7/site-packages (from en-core-web-sm==3.0.0) (3.0.6)
# Requirement already satisfied: typing-extensions&lt;4.0.0.0,&gt;=3.7.4 in /databricks/python3/lib/python3.7/site-packages (from spacy&lt;3.1.0,&gt;=3.0.0-&gt;en-core-web-sm==3.0.0) (3.10.0.0)
# Requirement already satisfied: preshed&lt;3.1.0,&gt;=3.0.2 in /databricks/python3/lib/python3.7/site-packages (from spacy&lt;3.1.0,&gt;=3.0.0-&gt;en-core-web-sm==3.0.0) (3.0.5)
# Requirement already satisfied: catalogue&lt;2.1.0,&gt;=2.0.3 in /databricks/python3/lib/python3.7/site-packages (from spacy&lt;3.1.0,&gt;=3.0.0-&gt;en-core-web-sm==3.0.0) (2.0.4)
# Requirement already satisfied: srsly&lt;3.0.0,&gt;=2.4.1 in /databricks/python3/lib/python3.7/site-packages (from spacy&lt;3.1.0,&gt;=3.0.0-&gt;en-core-web-sm==3.0.0) (2.4.1)
# Requirement already satisfied: jinja2 in /databricks/python3/lib/python3.7/site-packages (from spacy&lt;3.1.0,&gt;=3.0.0-&gt;en-core-web-sm==3.0.0) (2.11.3)
# Requirement already satisfied: blis&lt;0.8.0,&gt;=0.4.0 in /databricks/python3/lib/python3.7/site-packages (from spacy&lt;3.1.0,&gt;=3.0.0-&gt;en-core-web-sm==3.0.0) (0.7.4)
# Requirement already satisfied: thinc&lt;8.1.0,&gt;=8.0.3 in /databricks/python3/lib/python3.7/site-packages (from spacy&lt;3.1.0,&gt;=3.0.0-&gt;en-core-web-sm==3.0.0) (8.0.3)
# Requirement already satisfied: packaging&gt;=20.0 in /databricks/python3/lib/python3.7/site-packages (from spacy&lt;3.1.0,&gt;=3.0.0-&gt;en-core-web-sm==3.0.0) (20.9)
# Requirement already satisfied: pathy&gt;=0.3.5 in /databricks/python3/lib/python3.7/site-packages (from spacy&lt;3.1.0,&gt;=3.0.0-&gt;en-core-web-sm==3.0.0) (0.5.2)
# Requirement already satisfied: cymem&lt;2.1.0,&gt;=2.0.2 in /databricks/python3/lib/python3.7/site-packages (from spacy&lt;3.1.0,&gt;=3.0.0-&gt;en-core-web-sm==3.0.0) (2.0.5)
# Requirement already satisfied: wasabi&lt;1.1.0,&gt;=0.8.1 in /databricks/python3/lib/python3.7/site-packages (from spacy&lt;3.1.0,&gt;=3.0.0-&gt;en-core-web-sm==3.0.0) (0.8.2)
# Requirement already satisfied: numpy&gt;=1.15.0 in /databricks/python3/lib/python3.7/site-packages (from spacy&lt;3.1.0,&gt;=3.0.0-&gt;en-core-web-sm==3.0.0) (1.16.2)
# Requirement already satisfied: setuptools in /databricks/python3/lib/python3.7/site-packages (from spacy&lt;3.1.0,&gt;=3.0.0-&gt;en-core-web-sm==3.0.0) (56.0.0)
# Requirement already satisfied: tqdm&lt;5.0.0,&gt;=4.38.0 in /databricks/python3/lib/python3.7/site-packages (from spacy&lt;3.1.0,&gt;=3.0.0-&gt;en-core-web-sm==3.0.0) (4.60.0)
# Requirement already satisfied: murmurhash&lt;1.1.0,&gt;=0.28.0 in /databricks/python3/lib/python3.7/site-packages (from spacy&lt;3.1.0,&gt;=3.0.0-&gt;en-core-web-sm==3.0.0) (1.0.5)
# Requirement already satisfied: spacy-legacy&lt;3.1.0,&gt;=3.0.4 in /databricks/python3/lib/python3.7/site-packages (from spacy&lt;3.1.0,&gt;=3.0.0-&gt;en-core-web-sm==3.0.0) (3.0.5)
# Requirement already satisfied: typer&lt;0.4.0,&gt;=0.3.0 in /databricks/python3/lib/python3.7/site-packages (from spacy&lt;3.1.0,&gt;=3.0.0-&gt;en-core-web-sm==3.0.0) (0.3.2)
# Requirement already satisfied: pydantic&lt;1.8.0,&gt;=1.7.1 in /databricks/python3/lib/python3.7/site-packages (from spacy&lt;3.1.0,&gt;=3.0.0-&gt;en-core-web-sm==3.0.0) (1.7.3)
# Requirement already satisfied: requests&lt;3.0.0,&gt;=2.13.0 in /databricks/python3/lib/python3.7/site-packages (from spacy&lt;3.1.0,&gt;=3.0.0-&gt;en-core-web-sm==3.0.0) (2.23.0)
# Requirement already satisfied: zipp&gt;=0.5 in /databricks/python3/lib/python3.7/site-packages (from catalogue&lt;2.1.0,&gt;=2.0.3-&gt;spacy&lt;3.1.0,&gt;=3.0.0-&gt;en-core-web-sm==3.0.0) (3.4.1)
# Requirement already satisfied: pyparsing&gt;=2.0.2 in /databricks/python3/lib/python3.7/site-packages (from packaging&gt;=20.0-&gt;spacy&lt;3.1.0,&gt;=3.0.0-&gt;en-core-web-sm==3.0.0) (2.4.6)
# Requirement already satisfied: smart-open&lt;4.0.0,&gt;=2.2.0 in /databricks/python3/lib/python3.7/site-packages (from pathy&gt;=0.3.5-&gt;spacy&lt;3.1.0,&gt;=3.0.0-&gt;en-core-web-sm==3.0.0) (3.0.0)
# Requirement already satisfied: certifi&gt;=2017.4.17 in /databricks/python3/lib/python3.7/site-packages (from requests&lt;3.0.0,&gt;=2.13.0-&gt;spacy&lt;3.1.0,&gt;=3.0.0-&gt;en-core-web-sm==3.0.0) (2020.4.5.2)
# Requirement already satisfied: idna&lt;3,&gt;=2.5 in /databricks/python3/lib/python3.7/site-packages (from requests&lt;3.0.0,&gt;=2.13.0-&gt;spacy&lt;3.1.0,&gt;=3.0.0-&gt;en-core-web-sm==3.0.0) (2.9)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,&lt;1.26,&gt;=1.21.1 in /databricks/python3/lib/python3.7/site-packages (from requests&lt;3.0.0,&gt;=2.13.0-&gt;spacy&lt;3.1.0,&gt;=3.0.0-&gt;en-core-web-sm==3.0.0) (1.25.9)
# Requirement already satisfied: chardet&lt;4,&gt;=3.0.2 in /databricks/python3/lib/python3.7/site-packages (from requests&lt;3.0.0,&gt;=2.13.0-&gt;spacy&lt;3.1.0,&gt;=3.0.0-&gt;en-core-web-sm==3.0.0) (3.0.4)
# Requirement already satisfied: click&lt;7.2.0,&gt;=7.1.1 in /databricks/python3/lib/python3.7/site-packages (from typer&lt;0.4.0,&gt;=0.3.0-&gt;spacy&lt;3.1.0,&gt;=3.0.0-&gt;en-core-web-sm==3.0.0) (7.1.2)
# Requirement already satisfied: MarkupSafe&gt;=0.23 in /databricks/python3/lib/python3.7/site-packages (from jinja2-&gt;spacy&lt;3.1.0,&gt;=3.0.0-&gt;en-core-web-sm==3.0.0) (1.1.1)
# Installing collected packages: en-core-web-sm
#   Attempting uninstall: en-core-web-sm
#     Found existing installation: en-core-web-sm 2.3.1
#     Uninstalling en-core-web-sm-2.3.1:
#       Successfully uninstalled en-core-web-sm-2.3.1
# Successfully installed en-core-web-sm-3.0.0
# <span class="ansi-green-fg">✔ Download and installation successful</span>
# You can now load the package via spacy.load(&#39;en_core_web_sm&#39;)
# </div>

# %%
# %sh pip install networkx
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Requirement already satisfied: networkx in /databricks/python3/lib/python3.7/site-packages (2.5.1)
# Requirement already satisfied: decorator&lt;5,&gt;=4.3 in /databricks/python3/lib/python3.7/site-packages (from networkx) (4.4.1)
# </div>

# %%
import re
import pandas as pd
import bs4
import requests
import spacy
from spacy import displacy
nlp = spacy.load('en_core_web_sm')

from spacy.matcher import Matcher 
from spacy.tokens import Span 

import networkx as nx

import matplotlib.pyplot as plt
from tqdm import tqdm
from collections import defaultdict

pd.set_option('display.max_colwidth', 200)
# %matplotlib inline
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
candidate_sentences['Query'] = candidate_sentences['Query'].fillna('')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
color_dataset = pd.read_csv("/dbfs/FileStore/shared_uploads/t_karthik.ragunath@tatadigital.com/colours_rgb_shades.csv")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
color_dataset['Color Name'] = color_dataset['Color Name'].fillna('')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
color_names = []
for color in color_dataset['Color Name']:
    color_names.append(''.join(' ' + c if c.isupper() else c for c in color).lower().strip())
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
color_dataset['Color Names Cleaned'] = color_names
color_dataset['Color Names Cleaned'][:10]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[18]: 0                grey
# 1       grey,  silver
# 2                grey
# 3          light gray
# 4    light slate grey
# 5          slate gray
# 6         slate gray1
# 7         slate gray2
# 8         slate gray3
# 9         slate gray4
# Name: Color Names Cleaned, dtype: object</div>

# %%
from collections import defaultdict
check_df = pd.read_csv("/dbfs/FileStore/shared_uploads/t_karthik.ragunath@tatadigital.com/data_cleanser.csv",  header=0, delimiter='\t', error_bad_lines=False)
check_df['data_checker'] = check_df['data_checker'].fillna('')
data_checker_list = list(check_df['data_checker'])
max_len = 0
for ind_data in data_checker_list:
    comma_sep_data = ind_data.split(',')
    for datum in comma_sep_data:
        datum = ' '.join(datum.split())
        try:
            length = len(datum.split(' '))
        except:
            print(datum, comma_sep_data)
        if length > max_len:
            max_len = length

data_checker_dict = defaultdict(set)
data_checker_set = set(data_checker_list)
words_to_remove = ['Dress', 'Skirt', 'Black']
data_checker_set = set(filter(lambda x:(len(x)!=1 and x not in words_to_remove), data_checker_set))
for ind_data in data_checker_list:
    comma_sep_data = ind_data.split(',')
    for datum in comma_sep_data:
        datum = ' '.join(datum.split())
        datum_split = datum.split(' ')
        length = len(datum_split)
        initial_key = ""
        for i in range(length):
            data_checker_dict[initial_key].add(' '.join(datum_split[0:(i + 1)]))
            initial_key = ' '.join(datum_split[0:(i + 1)])
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">b&#39;Skipping line 1114: expected 1 fields, saw 2\nSkipping line 2126: expected 1 fields, saw 2\nSkipping line 2296: expected 1 fields, saw 2\nSkipping line 4922: expected 1 fields, saw 2\nSkipping line 9500: expected 1 fields, saw 2\nSkipping line 12578: expected 1 fields, saw 2\nSkipping line 15295: expected 1 fields, saw 2\nSkipping line 18309: expected 1 fields, saw 2\nSkipping line 21193: expected 1 fields, saw 2\nSkipping line 24723: expected 1 fields, saw 2\nSkipping line 35928: expected 1 fields, saw 2\nSkipping line 38161: expected 1 fields, saw 2\nSkipping line 47049: expected 1 fields, saw 2\nSkipping line 51626: expected 1 fields, saw 2\n&#39;
# </div>

# %%
max_len = 0
for ind_color in color_names:
    comma_sep_colors = ind_color.split(',')
    for color in comma_sep_colors:
        color = ' '.join(color.split())
        try:
            length = len(color.split(' '))
        except:
            print(color, comma_sep_colors)
        if length > max_len:
            max_len = length

color_dictionary = defaultdict(set)
color_set = set(color_names)
for ind_color in color_names:
    comma_sep_colors = ind_color.split(',')
    for color in comma_sep_colors:
        color = ' '.join(color.split())
        split_color = color.split(' ')
        length = len(split_color)
        initial_key = ""
        for i in range(length):
            color_dictionary[initial_key].add(' '.join(split_color[0:(i + 1)]))
            initial_key = ' '.join(split_color[0:(i + 1)])
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
check_df['data_checker'][:10]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[21]: 0           Gymboree
# 1    E-Land American
# 2               Soma
# 3    JoJo Maman Bebe
# 4       Abercrombie
# 5        Souris Mini
# 6     Janie and Jack
# 7               Puma
# 8             Merona
# 9     CCH Collection
# Name: data_checker, dtype: object</div>

# %%
len(data_checker_set)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[22]: 54741</div>

# %%
len(data_checker_dict.keys())
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[23]: 33574</div>

# %%
(color_dictionary.keys())
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[24]: dict_keys([&#39;&#39;, &#39;light&#39;, &#39;light slate&#39;, &#39;slate&#39;, &#39;dim&#39;, &#39;dark&#39;, &#39;dark slate&#39;, &#39;very&#39;, &#39;very light&#39;, &#39;free&#39;, &#39;free speech&#39;, &#39;alice&#39;, &#39;blue&#39;, &#39;cadet&#39;, &#39;corn&#39;, &#39;corn flower&#39;, &#39;cornflower&#39;, &#39;deep&#39;, &#39;deep sky&#39;, &#39;dodger&#39;, &#39;light sky&#39;, &#39;light steel&#39;, &#39;medium&#39;, &#39;medium slate&#39;, &#39;midnight&#39;, &#39;navy&#39;, &#39;pale&#39;, &#39;powder&#39;, &#39;royal&#39;, &#39;sky&#39;, &#39;steel&#39;, &#39;true&#39;, &#39;true iris&#39;, &#39;neon&#39;, &#39;new&#39;, &#39;new midnight&#39;, &#39;rich&#39;, &#39;summer&#39;, &#39;iris&#39;, &#39;rosy&#39;, &#39;saddle&#39;, &#39;sandy&#39;, &#34;baker&#39;s&#34;, &#39;semi-&#39;, &#39;semi- sweet&#39;, &#39;very dark&#39;, &#39;dark green&#39;, &#39;dark olive&#39;, &#39;dark sea&#39;, &#39;forest&#39;, &#39;green&#39;, &#39;lawn&#39;, &#39;light sea&#39;, &#39;lime&#39;, &#39;medium sea&#39;, &#39;medium spring&#39;, &#39;mint&#39;, &#39;olive&#39;, &#39;sea&#39;, &#39;spring&#39;, &#39;yellow&#39;, &#39;green yellow&#39;, &#39;hunter&#39;, &#39;hunter green&#39;, &#39;medium forest&#39;, &#39;peach&#39;, &#39;mandarian&#39;, &#39;orange&#39;, &#39;hot&#39;, &#39;indian&#39;, &#39;medium violet&#39;, &#39;misty&#39;, &#39;pale violet&#39;, &#39;violet&#39;, &#39;dusty&#39;, &#39;spicy&#39;, &#39;lavender&#39;, &#39;antique&#39;, &#39;floral&#39;, &#39;ghost&#39;, &#39;navajo&#39;, &#39;old&#39;, &#39;white&#39;, &#39;blanched&#39;, &#39;lemon&#39;, &#39;light goldenrod&#39;, &#39;papaya&#39;, &#39;cool&#39;, &#39;bronze&#39;, &#39;bronze i&#39;, &#39;bright&#39;, &#39;c&#39;, &#39;c s&#39;, &#39;c s s&#39;])</div>

# %%
symbol_extraction_dictionary = {
    "length_symbols":{
        "km",
        "hm",
        "dam",
        "m",
        "dm",
        "cm",
        "mm"
    },

    "length_values":{
        "kilometre",
        "hectometre",
        "decametre",
        "metre",
        "decimetre",
        "centimetre",
        "millimetre",
        "kilometer",
        "hectometer",
        "decameter",
        "meter",
        "decimeter",
        "centimeter",
        "millimeter"
    },

    "weight_symbols":{
        "t",
        "kg",
        "hg",
        "dag",
        "g",
        "dg",
        "cg", 
        "mg"
    },

    "weight_values":{
        "tonne",
        "kilogram",
        "hectogram",
        "decagram",
        "gram",
        "decigram",
        "centigram",
        "milligram"
    },

    "volume_symbols":{
        "kL",
        "hL",
        "daL",
        "L",
        "dL",
        "cL",
        "mL"
    },

    "volume_values":{
        "kilolitre",
        "hectolitre",
        "decalitre",
        "litre",
        "decilitre",
        "centilitre",
        "millilitre",
        "kiloliter",
        "hectoliter",
        "decaliter",
        "liter",
        "deciliter",
        "centiliter",
        "milliliter"
    }
}

value_symbol_conversion = {
    "kilometre": "km",
    "hectometre": "hm",
    "decametre": "dam",
    "metre": "m",
    "decimetre": "dm",
    "centimetre": "cm",
    "millimetre": "mm",
    "kilometer": "km",
    "hectometer": "hm",
    "decameter": "dam",
    "meter": "m",
    "decimeter": "dm",
    "centimeter": "cm",
    "millimeter": "mm",
    "kilometres": "km",
    "hectometres": "hm",
    "decametres": "dam",
    "metres": "m",
    "decimetres": "dm",
    "centimetres": "cm",
    "millimetres": "mm",
    "kilometers": "km",
    "hectometers": "hm",
    "decameters": "dam",
    "meters": "m",
    "decimeters": "dm",
    "centimeters": "cm",
    "millimeters": "mm",

    "tonne": "t",
    "kilogram":	"kg",
    "hectogram": "hg",
    "decagram":	"dag",
    "gram":	"g",
    "decigram":	"dg",
    "centigram": "cg",
    "milligram": "mg",
    "tonnes": "t",
    "kilograms": "kg",
    "hectograms": "hg",
    "decagrams": "dag",
    "grams": "g",
    "decigrams": "dg",
    "centigrams": "cg",
    "milligrams": "mg",

    "kilolitre": "kL",
    "hectolitre": "hL",
    "decalitre": "daL",
    "litre": "L",
    "decilitre": "dL",
    "centilitre": "cL",
    "millilitre": "mL",
    "kiloliter": "kL",
    "hectoliter": "hL",
    "decaliter": "daL",
    "liter": "L",
    "deciliter": "dL",
    "centiliter": "cL",
    "milliliter": "mL",
    "kilolitres": "kL",
    "hectolitres": "hL",
    "decalitres": "daL",
    "litres": "L",
    "decilitres": "dL",
    "centilitres": "cL",
    "millilitres": "mL",
    "kiloliters": "kL",
    "hectoliters": "hL",
    "decaliters": "daL",
    "liters": "L",
    "deciliters": "dL",
    "centiliters": "cL",
    "milliliters": "mL",
    
    "dollars": "$",
    "Dollars": "$",
    "dollar": "$",
    "Dollar": "$",
    "Euro": "€",
    "euro": "€",
    "Euros": "€",
    "euros": "€",
    "Pound": "£",
    "pound": "£",
    "Pounds": "£",
    "pounds": "£",
    "Rupee": "₹",
    "rupee": "₹",
    "Rupees": "₹",
    "rupees": "₹"
}
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
def get_preposition_meaning_refined(token, cur_string):
    left_string = ""
    right_string = ""
    for left_val in token.lefts:
        left_string += " " + left_val.text
        left_string = get_preposition_meaning_refined(left_val, left_string)
        
    for right_val in token.rights:
        right_string += " " + right_val.text
        right_string = get_preposition_meaning_refined(right_val, right_string)
        
    cur_string = left_string + " " + cur_string + " " + right_string
    cur_string = cur_string.strip()
    cur_string = " ".join(cur_string.split())
    return cur_string
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
def get_preposition_and_preposition_meaning(sent):
    doc = nlp(sent)
    doc_len = len(doc)
    i = 0
    preposition_list = []
    preposition_meaning_list = []
    while i < doc_len:
        tok = doc[i]
        if tok.dep_ == 'prep':
          prep_string = ""
          preposition_list.append(tok.text)
          print('N:', tok.text)
          preposition_meaning_list.append(get_preposition_meaning_refined(tok, prep_string))
        i += 1
    return preposition_list, preposition_meaning_list
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
string = "Playstation between 4000 and 5000 ₹"
get_preposition_and_preposition_meaning(string)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">N: between
# Out[101]: ([&#39;between&#39;], [&#39;4000 and 5000&#39;])</div>

# %%
def unsupervised_feature_extraction_dependency_extraction(sent):
    ## chunk 1
    substring_overlap_list = list(filter(lambda x: x in sent, value_symbol_conversion.keys()))
    substring_overlap_list_sorted = sorted(substring_overlap_list, key=len, reverse=True)
    for r in substring_overlap_list_sorted:
        sent = sent.replace(r, value_symbol_conversion[r])
    is_prev_tok_prep = False
    doc_num = nlp(sent)
    doc_num_len = len(doc_num)
    k = 0
    category_tok_indices = []
    word_2_num_dict = defaultdict()
    while k < doc_num_len:
        tok_n = doc_num[k]
        if tok_n.pos_.lower() == 'num':
            if not tok_n.text.isnumeric():
                word_num = tok_n.text
                l = k + 1
                while l < doc_num_len:
                    tok_n_next = doc_num[l]
                    if (tok_n_next.pos_.lower() == 'num' and not tok_n_next.text.isnumeric()):
                        word_num += " " + tok_n_next.text
                    elif tok_n_next.pos_.lower() == 'cconj':
                        if l + 1 < doc_num_len and (doc_num[l + 1].pos_.lower() == 'num' and not doc_num[l + 1].text.isnumeric()):
                            word_num += " " + tok_n_next.text
                        else:
                            break
                    else:
                        break
                    l += 1
                try:
                    word_2_num_dict[word_num] = w2n.word_to_num(word_num)
                except:
                    print('*'*10, 'word_num:', word_num, '*'*10)
                    nlp_word_num = nlp(word_num)
                    nlp_word_num_len = len(nlp_word_num)
                    word_num = ""
                    
                    for index in range(nlp_word_num_len):
                        word_tok = nlp_word_num[index]
                        print('@'*5, word_tok.text, word_tok.pos_.lower(), '@'*5)
                        if word_tok.pos_.lower() == 'num':
                            word_num += " " + word_tok.text
                            if index == (nlp_word_num_len - 1):
                                try:
                                    word_num = word_num.strip()
                                    print('#'*10, 'word_num:', word_num, '#'*10)
                                    word_2_num_dict[word_num] = w2n.word_to_num(word_num)
                                    word_num = ""
                                except:
                                    print("exception", "word num:", word_num)   
                        else:
                            try:
                                word_num = word_num.strip()
                                print('#'*10, 'word_num:', word_num, '#'*10)
                                word_2_num_dict[word_num] = w2n.word_to_num(word_num)
                                word_num = ""
                            except:
                                print("exception", "word num:", word_num)

                k = l - 1
        k += 1        
    for key, val in word_2_num_dict.items():
        sent = sent.replace(key, str(val))
    
#     print('sent updated:', sent)
    
    category_list = []
    quality_list = []
    preposition_list = []
    preposition_meaning_list = []
    
    prefix = ""
    modifier = ""
    category = ""
    doc = nlp(sent)
    doc_len = len(doc)
    i = 0
    while i < doc_len:
        tok = doc[i]        
        ## chunk 3: check if token is a modifier or not
        if tok.dep_.endswith("mod") == True and (tok.dep_.lower() != 'nummod' or (not is_prev_tok_prep and (not preposition_meaning_list or tok.text not in preposition_meaning_list[-1]))):
            modifier = prefix + " " + tok.text
            j = i + 1
            while j < doc_len:
                tok_next = doc[j]
                if tok_next.dep_.endswith("mod"):
                    modifier += " " + tok_next.text
                    j += 1
                else:
                    break
            i = j - 1
            modifier = modifier.strip()
            modifier = " ".join(modifier.split())
            quality_list.append(modifier)
            prefix = ""
            modifier = ""
            category = ""
            is_prev_tok_prep = False

        ## chunk 2: check if token is a noun or not    
        elif (tok.pos_.lower() == 'propn' or tok.pos_.lower() == 'noun') and (tok.dep_.lower() != 'pobj'):
            category = prefix + " " + tok.text
            j = i + 1
            while j < doc_len:
                tok_next = doc[j]
                if (tok_next.pos_.lower() == 'propn' or tok_next.pos_.lower() == 'noun') and (tok.dep_.lower() != 'pobj'):
                    category += " " + tok_next.text
                    j += 1
                else:
                    break
            
            category_tok_indices.append((i, j))
            i = j - 1
            category = category.strip()
            category = " ".join(category.split())
            category_list.append(category)
            prefix = ""
            modifier = ""
            category = ""
            is_prev_tok_prep = False

        
        ## chunk 4: check if token is a coumpuund word or not
        elif tok.dep_ != "punct" and tok.dep_.lower() == 'compound':
            prefix += " " + tok.text
            j = i + 1
            while j < doc_len:
                tok_next = doc[j]
                if tok_next.dep_.lower() == 'compound':
                    prefix += " " + tok_next.text
                    j += 1
                else:
                    break
            is_prev_tok_prep = False
                    
        elif tok.dep_ == 'prep':
            prep_string = ""
            preposition_list.append(tok.text)
            preposition_meaning_list.append(get_preposition_meaning_refined(tok, prep_string))
            is_prev_tok_prep = True
        
        else:
            is_prev_tok_prep = False
        
        i += 1

    category_feature_relation = []
    for cat_index, cat_tuple in enumerate(category_tok_indices):
        rel_found = False
        for tok_index in range(cat_tuple[0], cat_tuple[1]):
            tok = doc[tok_index]
            for child in tok.children:
                for quality in quality_list:
                    if child.text in quality:
                        category_feature_relation.append(category_list[cat_index] + ":" + quality)
                        rel_found = True
                        break
                if rel_found:
                    break
            if rel_found:
                break
            
    
    return quality_list, category_list, preposition_list, preposition_meaning_list, category_feature_relation
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
def unsupervised_feature_extraction_dependency_extraction_fashion(sent):
    ## chunk 1
    substring_overlap_list = list(filter(lambda x: x in sent, value_symbol_conversion.keys()))
    substring_overlap_list_sorted = sorted(substring_overlap_list, key=len, reverse=True)
    for r in substring_overlap_list_sorted:
        sent = sent.replace(r, value_symbol_conversion[r])
    is_prev_tok_prep = False
    doc_num = nlp(sent)
    doc_num_len = len(doc_num)
    k = 0
    category_tok_indices = []
    word_2_num_dict = defaultdict()
    while k < doc_num_len:
        tok_n = doc_num[k]
        if tok_n.pos_.lower() == 'num':
            if not tok_n.text.isnumeric():
                word_num = tok_n.text
                l = k + 1
                while l < doc_num_len:
                    tok_n_next = doc_num[l]
                    if (tok_n_next.pos_.lower() == 'num' and not tok_n_next.text.isnumeric()):
                        word_num += " " + tok_n_next.text
                    elif tok_n_next.pos_.lower() == 'cconj':
                        if l + 1 < doc_num_len and (doc_num[l + 1].pos_.lower() == 'num' and not doc_num[l + 1].text.isnumeric()):
                            word_num += " " + tok_n_next.text
                        else:
                            break
                    else:
                        break
                    l += 1
                try:
                    word_2_num_dict[word_num] = w2n.word_to_num(word_num)
                except:
                    print('*'*10, 'word_num:', word_num, '*'*10)
                    nlp_word_num = nlp(word_num)
                    nlp_word_num_len = len(nlp_word_num)
                    word_num = ""
                    
                    for index in range(nlp_word_num_len):
                        word_tok = nlp_word_num[index]
                        print('@'*5, word_tok.text, word_tok.pos_.lower(), '@'*5)
                        if word_tok.pos_.lower() == 'num':
                            word_num += " " + word_tok.text
                            if index == (nlp_word_num_len - 1):
                                try:
                                    word_num = word_num.strip()
                                    print('#'*10, 'word_num:', word_num, '#'*10)
                                    word_2_num_dict[word_num] = w2n.word_to_num(word_num)
                                    word_num = ""
                                except:
                                    print("exception", "word num:", word_num)   
                        else:
                            try:
                                word_num = word_num.strip()
                                print('#'*10, 'word_num:', word_num, '#'*10)
                                word_2_num_dict[word_num] = w2n.word_to_num(word_num)
                                word_num = ""
                            except:
                                print("exception", "word num:", word_num)

                k = l - 1
        k += 1        
    for key, val in word_2_num_dict.items():
        sent = sent.replace(key, str(val))
    
#     print('sent updated:', sent)
    
    category_list = []
    quality_list = []
    preposition_list = []
    preposition_meaning_list = []
    
    prefix = ""
    modifier = ""
    category = ""
    doc = nlp(sent)
    doc_len = len(doc)
    i = 0
    while i < doc_len:
        tok = doc[i]        
        ## chunk 2: check if token is a modifier or not
        if tok.dep_.endswith("mod") == True and (tok.dep_.lower() != 'nummod' or (not is_prev_tok_prep and (not preposition_meaning_list or tok.text not in preposition_meaning_list[-1]))):
            modifier = prefix + " " + tok.text
            j = i + 1
            while j < doc_len:
                tok_next = doc[j]
                if tok_next.dep_.endswith("mod"):
                    modifier += " " + tok_next.text
                    j += 1
                else:
                    break
            i = j - 1
            modifier = modifier.strip()
            modifier = " ".join(modifier.split())
            quality_list.append(modifier)
            prefix = ""
            modifier = ""
            category = ""
            is_prev_tok_prep = False
            
        ## chunk 3: check if token is a noun or not    
        elif (tok.pos_.lower() == 'propn' or tok.pos_.lower() == 'noun'):
            category = prefix + " " + tok.text
            j = i + 1
            while j < doc_len:
                tok_next = doc[j]
                if (tok_next.pos_.lower() == 'propn' or tok_next.pos_.lower() == 'noun'):
                    category += " " + tok_next.text
                    j += 1
                else:
                    break
            
            category_tok_indices.append((i, j))
            i = j - 1
            category = category.strip()
            category = " ".join(category.split())
            category_list.append(category)
            prefix = ""
            modifier = ""
            category = ""
            is_prev_tok_prep = False
            
        ## chunk 4: check if token is a coumpuund word or not
        elif tok.dep_ != "punct" and (tok.dep_.lower() == 'compound' or (tok.pos_.lower() != 'propn' and tok.pos_.lower() != 'noun' and tok.dep_.lower() == 'root')):
            prefix = tok.text
            j = i + 1
            while j < doc_len:
                tok_next = doc[j]
                if tok_next.dep_.lower() == 'compound' or (tok_next.pos_.lower() != 'propn' and tok_next.pos_.lower() != 'noun' and tok_next.dep_.lower() == 'root'):
                    prefix += " " + tok_next.text
                    j += 1
                else:
                    break
            i = j - 1
            quality_list.append(prefix)
            prefix = ""
            modifier = ""
            category = ""
            is_prev_tok_prep = False
                  
        ## chunk 5: check if token is a prep or not and to extract meaning around preposition
        elif tok.dep_ == 'prep':
            prep_string = ""
            preposition_list.append(tok.text)
            preposition_meaning_list.append(get_preposition_meaning_refined(tok, prep_string))
            is_prev_tok_prep = True
        
        else:
            is_prev_tok_prep = False
        
        i += 1

    category_feature_relation = []
    for cat_index, cat_tuple in enumerate(category_tok_indices):
        quality_set = set()
        for tok_index in range(cat_tuple[0], cat_tuple[1]):
            tok = doc[tok_index]
            for child in tok.children:
                for quality in quality_list:
                    if child.text in quality and quality not in quality_set:
                        category_feature_relation.append(category_list[cat_index] + ":" + quality)
                        quality_set.add(quality)
                        break
            
    
    return quality_list, category_list, preposition_list, preposition_meaning_list, category_feature_relation
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# unsupervised_feature_extraction_dependency_extraction("Android Phone 6GB RAM below 7 inches")
unsupervised_feature_extraction_dependency_extraction("Floral print midi dress")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[56]: ([&#39;Floral&#39;], [&#39;print midi dress&#39;], [], [], [&#39;print midi dress:Floral&#39;])</div>

# %%
# string = "Android Phone 6GB RAM below 7 inches"
# string = "Off Shoulder Dress"
# string = "Floral print midi dress"
string = "red sheath dress"
doc = nlp(string)
for tok in doc:
    print(tok.text, tok.dep_, tok.pos_, tok.lemma_)
    for child in tok.children:
        print('child:', child, 'type:', type(child))
    for child in tok.rights:
        print('rights:', child, 'type:', type(child))
    for child in tok.lefts:
        print('lefts:', child, 'type:', type(child))
for ent in doc.ents:
    print(ent.text, ent.start_char, ent.end_char, ent.label_)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">red amod ADJ red
# sheath amod ADJ sheath
# dress ROOT NOUN dress
# child: red type: &lt;class &#39;spacy.tokens.token.Token&#39;&gt;
# child: sheath type: &lt;class &#39;spacy.tokens.token.Token&#39;&gt;
# lefts: red type: &lt;class &#39;spacy.tokens.token.Token&#39;&gt;
# lefts: sheath type: &lt;class &#39;spacy.tokens.token.Token&#39;&gt;
# </div>

# %%
# import spacy
# from spacy import displacy

# nlp = spacy.load('en_core_web_sm')

# from spacy.matcher import Matcher 
# from spacy.tokens import Span 
# string = "Android Phone 6GB RAM below 7 inches"
# doc = nlp(string)
# for tok in doc:
#     print(tok.text, tok.dep_, tok.pos_, tok.lemma_)
#     for child in tok.children:
#         print('child:', child, 'type:', type(child))
#     for child in tok.rights:
#         print('rights:', child, 'type:', type(child))
#     for child in tok.lefts:
#         print('lefts:', child, 'type:', type(child))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
unsupervised_feature_extraction_dependency_extraction_fashion("Off Shoulder Dress")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[45]: ([&#39;Off Shoulder&#39;], [&#39;Dress&#39;], [], [], [&#39;Dress:Off Shoulder&#39;])</div>

# %%
candidate_sentences['Query'] = candidate_sentences['Query'].fillna('')
quality_tags_list = []
category_tags_list = []
brand_list = []
preposition_list = [] 
preposition_meaning_list = []
category_feature_relation_list = []
# for k in tqdm(prep_df["search_text"]):
for k in tqdm(candidate_sentences["Query"]):
    sentence_split = k.split()
    split_len = len(sentence_split)
    brand_str = ""
    initial_key = ""
    
    for i in range(split_len):
        if sentence_split[i] in data_checker_dict[""]:
            start_index = i
            j = 2
            loop_index = i + 1
            brand_tuple_index = tuple()
            while loop_index <= split_len and " ".join(sentence_split[start_index:loop_index]) in data_checker_dict[" ".join(sentence_split[start_index:(loop_index - 1)])]:
                if " ".join(sentence_split[start_index:loop_index]) in data_checker_set:
                    brand_tuple_index = (start_index, loop_index) 
                j += 1
                loop_index += 1
            if brand_tuple_index:
                brand_str = ' '.join(sentence_split[brand_tuple_index[0]:brand_tuple_index[1]])
                brand_list.append(brand_str)
                print('brand:', brand_str, 'sentence:', k)
                sentence_split[brand_tuple_index[0]:brand_tuple_index[1]] = []
                break
    if not brand_str:
        brand_list.append("")
    k = ' '.join(sentence_split)
    quality_tags, category_tags, preposition_tags, preposition_meaning_tags, category_feature_relation = unsupervised_feature_extraction_dependency_extraction_fashion(k)
    quality_tags_list.append(quality_tags)
    category_tags_list.append(category_tags)
    preposition_list.append(preposition_tags)
    preposition_meaning_list.append(preposition_meaning_tags)
    category_feature_relation_list.append(category_feature_relation)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
#   0%|          | 0/613 [00:00&lt;?, ?it/s]brand: Fendi sentence: Fendi handbag
# brand: Fendi sentence: Fendi beige handbag
#   1%|          | 6/613 [00:00&lt;00:10, 58.51it/s]brand: FURLA sentence: FURLA pochette
# brand: Coach sentence: Coach work bag
#   2%|▏         | 15/613 [00:00&lt;00:07, 75.84it/s]brand: Burberry sentence: Burberry duffel bag
#   6%|▋         | 39/613 [00:00&lt;00:07, 76.19it/s]brand: Alice sentence: Alice Mccall midi dress
#  11%|█         | 65/613 [00:00&lt;00:06, 79.15it/s]brand: Brandon Maxwell sentence: Brandon Maxwell Blouse
#  13%|█▎        | 82/613 [00:01&lt;00:06, 80.07it/s]brand: Gucci sentence: Gucci sweatshirt
# brand: MARNI sentence: MARNI tube top
#  16%|█▋        | 100/613 [00:01&lt;00:06, 79.78it/s]brand: FRAME sentence: FRAME dark wash jeans
#  19%|█▉        | 116/613 [00:01&lt;00:06, 79.25it/s]brand: Balmain sentence: Balmain shorts
# brand: Miguelina sentence: Miguelina Shorts
#  22%|██▏       | 134/613 [00:01&lt;00:05, 83.38it/s]brand: Theory sentence: Theory light grey coat
#  28%|██▊       | 170/613 [00:02&lt;00:05, 83.43it/s]brand: Gucci sentence: Gucci watch
#  29%|██▉       | 179/613 [00:02&lt;00:05, 83.40it/s]brand: Calvin Klein sentence: Calvin Klein briefs
# brand: Carine sentence: Carine Gilson bustier
# brand: Paul Smith sentence:  Paul Smith socks
#  34%|███▎      | 206/613 [00:02&lt;00:05, 78.47it/s]brand: Prada sentence: Prada  sunglasses
# brand: Chloe sentence: Chloe wallet
#  35%|███▌      | 215/613 [00:02&lt;00:04, 79.63it/s]brand: Valentino sentence: Valentino pouch
#  36%|███▋      | 223/613 [00:02&lt;00:04, 78.39it/s]brand: Gianvito Rossi sentence: Gianvito Rossi boots
# brand: Jimmy Choo sentence: Jimmy Choo flats
#  38%|███▊      | 231/613 [00:02&lt;00:04, 78.11it/s]brand: Aquazzura sentence: Aquazzura high heels
# brand: Aquazzura sentence: Aquazzura stiletto
# brand: GAIA sentence: CULT GAIA sandals
#  39%|███▉      | 240/613 [00:03&lt;00:04, 78.75it/s]brand: ETRO sentence: men ETRO green polo shirt
# brand: ETRO sentence: men ETRO polo shirt
#  41%|████      | 252/613 [00:03&lt;00:04, 88.29it/s]brand: MARNI sentence: men MARNI solid red sweatshirt
# brand: Dolce &amp; Gabbana sentence: men Dolce &amp; Gabbana green cardigan
#  46%|████▌     | 280/613 [00:03&lt;00:02, 112.30it/s]brand: Jennifer Taylor sentence: Jennifer Taylor tufted sofa
# brand: Jennifer Taylor sentence: Jennifer Taylor tufted camelback sofa
# brand: Jennifer Taylor sentence: Jennifer Taylor tufted camelback sofa cream
#  48%|████▊     | 292/613 [00:03&lt;00:02, 109.95it/s]brand: Armen sentence: Armen Living dining table
# brand: Armen sentence: rustic oak Armen Living dining table
#  50%|████▉     | 304/613 [00:03&lt;00:02, 105.12it/s]brand: Chic sentence:  Home Chic adjustable bar stool
#  60%|█████▉    | 367/613 [00:04&lt;00:02, 89.21it/s]brand: Alice sentence: Alice Mccall midi dress
#  66%|██████▌   | 403/613 [00:04&lt;00:02, 86.29it/s]brand: Brandon Maxwell sentence: Brandon Maxwell Blouse
#  67%|██████▋   | 412/613 [00:04&lt;00:02, 85.13it/s]brand: Gucci sentence: Gucci sweatshirt
#  70%|███████   | 430/613 [00:05&lt;00:02, 81.74it/s]brand: FRAME sentence: FRAME dark wash jeans
#  73%|███████▎  | 448/613 [00:05&lt;00:02, 79.48it/s]brand: Bassike sentence: Bassike shorts
#  75%|███████▍  | 457/613 [00:05&lt;00:01, 80.60it/s]brand: Miguelina sentence: Miguelina Shorts
#  77%|███████▋  | 475/613 [00:05&lt;00:01, 83.78it/s]brand: Ganni sentence: Ganni bikinis
#  79%|███████▉  | 484/613 [00:05&lt;00:01, 83.95it/s]brand: Zimmermann sentence: Zimmermann Bikinis
#  80%|████████  | 493/613 [00:05&lt;00:01, 81.45it/s]brand: Suzanne sentence: Suzanne Kalan earrings
#  83%|████████▎ | 511/613 [00:06&lt;00:01, 83.08it/s]brand: Pomellato sentence: Pomellato Nudo rings
# brand: Gucci sentence: Gucci watch
# brand: Cartier sentence: Cartier tank watch
#  86%|████████▋ | 529/613 [00:06&lt;00:01, 82.44it/s]brand: Calvin Klein sentence: Calvin Klein briefs
#  88%|████████▊ | 538/613 [00:06&lt;00:00, 80.77it/s]brand: SPANX sentence: SPANX  bodysuit
#  91%|█████████ | 556/613 [00:06&lt;00:00, 77.26it/s]brand: Balenciaga sentence: Balenciaga baseball cap
# brand: Clyde sentence: Clyde sunhat
# brand: Prada sentence: Prada  sunglasses
# brand: Alaia sentence: Alaia acetate sunglasses
#  92%|█████████▏| 564/613 [00:06&lt;00:00, 77.27it/s]brand: Chloe sentence: Chloe wallet
# brand: Valentino sentence: Valentino pouch
#  95%|█████████▍| 580/613 [00:06&lt;00:00, 75.54it/s]brand: Gianvito Rossi sentence: Gianvito Rossi boots
# brand: Jimmy Choo sentence: Jimmy Choo flats
#  96%|█████████▌| 589/613 [00:07&lt;00:00, 77.79it/s]brand: Aquazzura sentence: Aquazzura high heels
# brand: GAIA sentence: CULT GAIA leather sandals
#  98%|█████████▊| 598/613 [00:07&lt;00:00, 78.98it/s]brand: Chloe sentence: Chloe kids cardigan
#  99%|█████████▉| 607/613 [00:07&lt;00:00, 79.67it/s]brand: Baby sentence: Baby dress
# 100%|██████████| 613/613 [00:07&lt;00:00, 83.73it/s]
# </div>

# %%
qa_tag_extraction = pd.DataFrame(columns=['Query','Brand', 'Quality', 'Category', 'Preposition', 'Preposition Meaning'])
qa_tag_extraction['Query'] = list(candidate_sentences["Query"])
qa_tag_extraction['Brand'] = brand_list
qa_tag_extraction['Quality'] = quality_tags_list
qa_tag_extraction['Category'] = category_tags_list
qa_tag_extraction['Preposition'] = preposition_list
qa_tag_extraction['Preposition Meaning'] = preposition_meaning_list
qa_tag_extraction['Category_Feature_Relation'] = category_feature_relation_list
qa_tag_extraction.to_csv('/dbfs/mnt/croma/msd/tobeprocessed/qa_queries_ner_tagger_extraction_with_relation.csv', encoding='utf-8')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
dbutils.fs.mounts()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[49]: [MountInfo(mountPoint=&#39;/mnt/tatasky&#39;, source=&#39;abfss://tatasky-data@statddevdecidatgrs04.dfs.core.windows.net&#39;, encryptionType=&#39;&#39;),
#  MountInfo(mountPoint=&#39;/mnt/msd-starfire&#39;, source=&#39;wasbs://msd-starfire@statddevdemsdci02.blob.core.windows.net&#39;, encryptionType=&#39;&#39;),
#  MountInfo(mountPoint=&#39;/databricks-datasets&#39;, source=&#39;databricks-datasets&#39;, encryptionType=&#39;&#39;),
#  MountInfo(mountPoint=&#39;/mnt/delta-table&#39;, source=&#39;wasbs://delta-table@statddevdemsdci02.blob.core.windows.net&#39;, encryptionType=&#39;&#39;),
#  MountInfo(mountPoint=&#39;/mnt/delta-load-prod&#39;, source=&#39;wasbs://ingestion-delta-load@statdprdprmsdci02.blob.core.windows.net&#39;, encryptionType=&#39;&#39;),
#  MountInfo(mountPoint=&#39;/mnt/tatacliq&#39;, source=&#39;abfss://tatacliq@statddevdecidatgrs04.dfs.core.windows.net&#39;, encryptionType=&#39;&#39;),
#  MountInfo(mountPoint=&#39;/mnt/bigbasket_sit2&#39;, source=&#39;abfss://bigbasket@statdprpppcidatgrs04.dfs.core.windows.net&#39;, encryptionType=&#39;&#39;),
#  MountInfo(mountPoint=&#39;/databricks/mlflow-tracking&#39;, source=&#39;databricks/mlflow-tracking&#39;, encryptionType=&#39;&#39;),
#  MountInfo(mountPoint=&#39;/databricks-results&#39;, source=&#39;databricks-results&#39;, encryptionType=&#39;&#39;),
#  MountInfo(mountPoint=&#39;/databricks/mlflow-registry&#39;, source=&#39;databricks/mlflow-registry&#39;, encryptionType=&#39;&#39;),
#  MountInfo(mountPoint=&#39;/mnt/siebel-sunset&#39;, source=&#39;abfss://siebel-sunset@statddevdecidatgrs04.dfs.core.windows.net&#39;, encryptionType=&#39;&#39;),
#  MountInfo(mountPoint=&#39;/mnt/starbucks&#39;, source=&#39;abfss://starbucks@statddevdecidatgrs04.dfs.core.windows.net&#39;, encryptionType=&#39;&#39;),
#  MountInfo(mountPoint=&#39;/mnt/events&#39;, source=&#39;wasbs://events@statddevdemsdci02.blob.core.windows.net&#39;, encryptionType=&#39;&#39;),
#  MountInfo(mountPoint=&#39;/mnt/airasia&#39;, source=&#39;abfss://airasia@statddevdecidatgrs04.dfs.core.windows.net&#39;, encryptionType=&#39;&#39;),
#  MountInfo(mountPoint=&#39;/mnt/tcp&#39;, source=&#39;abfss://tcp@statddevdecidatgrs04.dfs.core.windows.net&#39;, encryptionType=&#39;&#39;),
#  MountInfo(mountPoint=&#39;/mnt/bigbasket-new&#39;, source=&#39;abfss://bigbasket@statddevdecidatgrs04.dfs.core.windows.net&#39;, encryptionType=&#39;&#39;),
#  MountInfo(mountPoint=&#39;/mnt/tatacliq_sit2&#39;, source=&#39;abfss://tatacliq@statdprpppcidatgrs04.dfs.core.windows.net&#39;, encryptionType=&#39;&#39;),
#  MountInfo(mountPoint=&#39;/mnt/bigbasket&#39;, source=&#39;abfss://bigbasket@statddevdecidatgrs04.dfs.core.windows.net&#39;, encryptionType=&#39;&#39;),
#  MountInfo(mountPoint=&#39;/mnt/ihcl&#39;, source=&#39;abfss://ihcl-data@statddevdecidatgrs04.dfs.core.windows.net&#39;, encryptionType=&#39;&#39;),
#  MountInfo(mountPoint=&#39;/mnt/croma&#39;, source=&#39;abfss://chroma-data@statddevdecidatgrs04.dfs.core.windows.net&#39;, encryptionType=&#39;&#39;),
#  MountInfo(mountPoint=&#39;/mnt/nemo&#39;, source=&#39;wasbs://client-data@statddevdemsdci02.blob.core.windows.net&#39;, encryptionType=&#39;&#39;),
#  MountInfo(mountPoint=&#39;/&#39;, source=&#39;DatabricksRoot&#39;, encryptionType=&#39;&#39;)]</div>

# %%
display(qa_tag_extraction)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Query</th><th>Brand</th><th>Quality</th><th>Category</th><th>Preposition</th><th>Preposition Meaning</th><th>Category_Feature_Relation</th></tr></thead><tbody><tr><td>bag</td><td></td><td>List()</td><td>List(bag)</td><td>List()</td><td>List()</td><td>List()</td></tr><tr><td>Fendi handbag</td><td>Fendi</td><td>List()</td><td>List(handbag)</td><td>List()</td><td>List()</td><td>List()</td></tr><tr><td>Fendi beige handbag</td><td>Fendi</td><td>List(beige)</td><td>List(handbag)</td><td>List()</td><td>List()</td><td>List(handbag:beige)</td></tr><tr><td>backpacks</td><td></td><td>List()</td><td>List(backpacks)</td><td>List()</td><td>List()</td><td>List()</td></tr><tr><td>black backpacks</td><td></td><td>List(black)</td><td>List(backpacks)</td><td>List()</td><td>List()</td><td>List(backpacks:black)</td></tr><tr><td>blue bucket bag</td><td></td><td>List(blue, bucket)</td><td>List(bag)</td><td>List()</td><td>List()</td><td>List(bag:bucket)</td></tr><tr><td>bucketbag</td><td></td><td>List()</td><td>List(bucketbag)</td><td>List()</td><td>List()</td><td>List()</td></tr><tr><td>crocodile print bag</td><td></td><td>List(crocodile print)</td><td>List(bag)</td><td>List()</td><td>List()</td><td>List(bag:crocodile print)</td></tr><tr><td>animal print bag</td><td></td><td>List(animal print)</td><td>List(bag)</td><td>List()</td><td>List()</td><td>List(bag:animal print)</td></tr><tr><td>tote bag</td><td></td><td>List(tote)</td><td>List(bag)</td><td>List()</td><td>List()</td><td>List()</td></tr><tr><td>totes</td><td></td><td>List()</td><td>List(totes)</td><td>List()</td><td>List()</td><td>List()</td></tr><tr><td>FURLA pochette</td><td>FURLA</td><td>List()</td><td>List(pochette)</td><td>List()</td><td>List()</td><td>List()</td></tr><tr><td>red CELINE crossbody </td><td></td><td>List(red, CELINE)</td><td>List(crossbody)</td><td>List()</td><td>List()</td><td>List(crossbody:CELINE)</td></tr><tr><td>Coach work bag</td><td>Coach</td><td>List(work)</td><td>List(bag)</td><td>List()</td><td>List()</td><td>List(bag:work)</td></tr><tr><td>pink coccinelle bum bag</td><td></td><td>List(pink, coccinelle bum)</td><td>List(bag)</td><td>List()</td><td>List()</td><td>List(bag:pink, bag:coccinelle bum)</td></tr><tr><td>belt bag</td><td></td><td>List(belt)</td><td>List(bag)</td><td>List()</td><td>List()</td><td>List(bag:belt)</td></tr><tr><td>Burberry duffel bag</td><td>Burberry</td><td>List(duffel)</td><td>List(bag)</td><td>List()</td><td>List()</td><td>List(bag:duffel)</td></tr><tr><td>faux leather wallet</td><td></td><td>List(faux, leather)</td><td>List(wallet)</td><td>List()</td><td>List()</td><td>List(wallet:leather)</td></tr><tr><td>pale pink wallet</td><td></td><td>List(pale pink)</td><td>List(wallet)</td><td>List()</td><td>List()</td><td>List(wallet:pale pink)</td></tr><tr><td>Floral print midi dress</td><td></td><td>List(Floral, print midi)</td><td>List(dress)</td><td>List()</td><td>List()</td><td>List(dress:Floral, dress:print midi)</td></tr><tr><td>red sheath dress</td><td></td><td>List(red sheath)</td><td>List(dress)</td><td>List()</td><td>List()</td><td>List(dress:red sheath)</td></tr><tr><td>little black dress</td><td></td><td>List(little black)</td><td>List(dress)</td><td>List()</td><td>List()</td><td>List(dress:little black)</td></tr><tr><td>yellow short sleeve mini dress</td><td></td><td>List(yellow short sleeve mini)</td><td>List(dress)</td><td>List()</td><td>List()</td><td>List(dress:yellow short sleeve mini)</td></tr><tr><td>burgundy crewneck dress</td><td></td><td>List(burgundy crewneck)</td><td>List(dress)</td><td>List()</td><td>List()</td><td>List(dress:burgundy crewneck)</td></tr><tr><td>crew neck dress</td><td></td><td>List(crew neck)</td><td>List(dress)</td><td>List()</td><td>List()</td><td>List(dress:crew neck)</td></tr><tr><td>Off Shoulder Dress</td><td></td><td>List(Off Shoulder)</td><td>List(Dress)</td><td>List()</td><td>L ...

# %%
nlp_update = spacy.load('en_core_web_sm')
string = "red sheath dress"
doc = nlp_update(string)
for tok in doc:
    print(tok.text, tok.dep_, tok.pos_, tok.lemma_)
    for child in tok.children:
        print('child:', child, 'type:', type(child))
    for child in tok.rights:
        print('rights:', child, 'type:', type(child))
    for child in tok.lefts:
        print('lefts:', child, 'type:', type(child))
for ent in doc.ents:
    print(ent.text, ent.start_char, ent.end_char, ent.label_)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">red amod ADJ red
# sheath amod ADJ sheath
# dress ROOT NOUN dress
# child: red type: &lt;class &#39;spacy.tokens.token.Token&#39;&gt;
# child: sheath type: &lt;class &#39;spacy.tokens.token.Token&#39;&gt;
# lefts: red type: &lt;class &#39;spacy.tokens.token.Token&#39;&gt;
# lefts: sheath type: &lt;class &#39;spacy.tokens.token.Token&#39;&gt;
# </div>

# %%
color_dataset['Color Names Cleaned'][:10]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[61]: 0                grey
# 1       grey,  silver
# 2                grey
# 3          light gray
# 4    light slate grey
# 5          slate gray
# 6         slate gray1
# 7         slate gray2
# 8         slate gray3
# 9         slate gray4
# Name: Color Names Cleaned, dtype: object</div>

# %%
training_color_data = []
#actually annotaion must be done with context and not as empty words
for color_name in color_dataset['Color Names Cleaned']:
  training_color_data.append((color_name, {"entities":[(0, len(color_name), "COLOR")]}))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
import random
from spacy.training import Example
path_to_model = '/dbfs/mnt/nemo/'
batch_sizes = spacy.util.compounding(4.0, 32.0, 1.001)
optimizer = nlp_update.resume_training()
for i in range(5):
  random.shuffle(training_color_data)
  for batch in spacy.util.minibatch(training_color_data, size=batch_sizes):
    '''https://www.youtube.com/watch?v=THduWAnG97k'''
#     texts = [text for text, annotation in batch]
#     annotations = [annotation for text, annotation in batch]
#     nlp_update.update(texts, annotations)
    examples=[]
    for text, annotations in batch: #https://stackoverflow.com/questions/66377634/convert-code-from-spacy2-to-spacy3-nlp-update-not-working
      doc = nlp_update.make_doc(text)
      example = Example.from_dict(doc, annotations)
      examples.append(example)
    losses = {}
    nlp_update.update(examples, sgd=optimizer, drop=0.35, losses=losses)
nlp_update.to_disk(path_to_model)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# string = "red sheath dress"
# string = "animal print dress"
# string = "Android Phone under 6GB RAM"
# string = "pale pink wallet"
# string = "full sleeve crop top"
string = "crew neck dress"
doc = nlp_update(string)
for tok in doc:
    print(tok.text, tok.dep_, tok.pos_, tok.lemma_)
    for child in tok.children:
        print('child:', child, 'type:', type(child))
    for child in tok.rights:
        print('rights:', child, 'type:', type(child))
    for child in tok.lefts:
        print('lefts:', child, 'type:', type(child))
for ent in doc.ents:
    print(ent.text, ent.start_char, ent.end_char, ent.label_)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">crew compound NOUN crew
# neck compound NOUN neck
# child: crew type: &lt;class &#39;spacy.tokens.token.Token&#39;&gt;
# lefts: crew type: &lt;class &#39;spacy.tokens.token.Token&#39;&gt;
# dress ROOT NOUN dress
# child: neck type: &lt;class &#39;spacy.tokens.token.Token&#39;&gt;
# lefts: neck type: &lt;class &#39;spacy.tokens.token.Token&#39;&gt;
# crew neck dress 0 15 COLOR
# </div>

# %%
def clean_text(str_data):
    str_data = str_data.strip()
    str_data = " ".join(str_data.split())
    return str_data
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
def unsupervised_feature_extraction_dependency_extraction_fashion_augmented(sent):
    ## chunk 1
    substring_overlap_list = list(filter(lambda x: x in sent, value_symbol_conversion.keys()))
    substring_overlap_list_sorted = sorted(substring_overlap_list, key=len, reverse=True)
    for r in substring_overlap_list_sorted:
        sent = sent.replace(r, value_symbol_conversion[r])
    is_prev_tok_prep = False
    doc_num = nlp(sent)
    doc_num_len = len(doc_num)
    k = 0
    category_tok_indices = []
    word_2_num_dict = defaultdict()
    while k < doc_num_len:
        tok_n = doc_num[k]
        if tok_n.pos_.lower() == 'num':
            if not tok_n.text.isnumeric():
                word_num = tok_n.text
                l = k + 1
                while l < doc_num_len:
                    tok_n_next = doc_num[l]
                    if (tok_n_next.pos_.lower() == 'num' and not tok_n_next.text.isnumeric()):
                        word_num += " " + tok_n_next.text
                    elif tok_n_next.pos_.lower() == 'cconj':
                        if l + 1 < doc_num_len and (doc_num[l + 1].pos_.lower() == 'num' and not doc_num[l + 1].text.isnumeric()):
                            word_num += " " + tok_n_next.text
                        else:
                            break
                    else:
                        break
                    l += 1
                try:
                    word_2_num_dict[word_num] = w2n.word_to_num(word_num)
                except:
                    print('*'*10, 'word_num:', word_num, '*'*10)
                    nlp_word_num = nlp(word_num)
                    nlp_word_num_len = len(nlp_word_num)
                    word_num = ""
                    
                    for index in range(nlp_word_num_len):
                        word_tok = nlp_word_num[index]
                        print('@'*5, word_tok.text, word_tok.pos_.lower(), '@'*5)
                        if word_tok.pos_.lower() == 'num':
                            word_num += " " + word_tok.text
                            if index == (nlp_word_num_len - 1):
                                try:
                                    word_num = word_num.strip()
                                    print('#'*10, 'word_num:', word_num, '#'*10)
                                    word_2_num_dict[word_num] = w2n.word_to_num(word_num)
                                    word_num = ""
                                except:
                                    print("exception", "word num:", word_num)   
                        else:
                            try:
                                word_num = word_num.strip()
                                print('#'*10, 'word_num:', word_num, '#'*10)
                                word_2_num_dict[word_num] = w2n.word_to_num(word_num)
                                word_num = ""
                            except:
                                print("exception", "word num:", word_num)

                k = l - 1
        k += 1        
    for key, val in word_2_num_dict.items():
        sent = sent.replace(key, str(val))
    
#     print('sent updated:', sent)
    
    category_list = []
    quality_list = []
    preposition_list = []
    preposition_meaning_list = []
    
    prefix = ""
    modifier = ""
    category = ""
    doc = nlp(sent)
    doc_len = len(doc)
    i = 0
    while i < doc_len:
        tok = doc[i]        
        ## chunk 2: check if token is a modifier or not
        if tok.dep_.endswith("mod") == True and (tok.dep_.lower() != 'nummod' or (not is_prev_tok_prep and (not preposition_meaning_list or tok.text not in preposition_meaning_list[-1]))):
            modifier = tok.text
            j = i + 1
            while j < doc_len:
                tok_next = doc[j]
                if tok_next.dep_.endswith("mod"):
                    cleaned_text = clean_text(modifier)
                    quality_list.append(cleaned_text)
                    modifier = tok_next.text
                    j += 1
                else:
                    break
            i = j - 1
            cleaned_text = clean_text(modifier)
            quality_list.append(cleaned_text)
            prefix = ""
            modifier = ""
            category = ""
            is_prev_tok_prep = False
            
        ## chunk 2: check if token is a coumpuund word or not
        elif tok.dep_ != "punct" and (tok.dep_.lower() == 'compound' and (tok.pos_.lower() != 'propn' and tok.pos_.lower() != 'noun' and tok.dep_.lower() != 'root')):
            prefix = tok.text
            j = i + 1
            while j < doc_len:
                tok_next = doc[j]
                if tok_next.dep_.lower() == 'compound' or (tok_next.pos_.lower() != 'propn' and tok_next.pos_.lower() != 'noun' and tok_next.dep_.lower() != 'root'):
                    prefix += " " + tok_next.text
                    j += 1
                else:
                    break
            i = j - 1
            quality_list.append(prefix)
            prefix = ""
            modifier = ""
            category = ""
            is_prev_tok_prep = False
            
        ## chunk 3: check if token is a coumpuund word or not
        elif tok.dep_ != "punct" and (tok.dep_.lower() == 'compound' and (tok.pos_.lower() == 'propn' or tok.pos_.lower() == 'noun' or tok.dep_.lower() == 'root')):
            prefix = tok.text
            j = i + 1
            while j < doc_len:
                tok_next = doc[j]
                if tok_next.dep_.lower() == 'compound' or (tok_next.pos_.lower() == 'propn' or tok_next.pos_.lower() == 'noun' or tok_next.dep_.lower() == 'root'):
                    prefix += " " + tok_next.text
                    j += 1
                else:
                    break
            i = j - 1
            category_list.append(prefix)
            prefix = ""
            modifier = ""
            category = ""
            is_prev_tok_prep = False
            
        ## chunk 3: check if token is a noun or not    
        elif (tok.pos_.lower() == 'propn' or tok.pos_.lower() == 'noun'):
            category = prefix + " " + tok.text
            j = i + 1
            while j < doc_len:
                tok_next = doc[j]
                if (tok_next.pos_.lower() == 'propn' or tok_next.pos_.lower() == 'noun'):
                    category += " " + tok_next.text
                    j += 1
                else:
                    break
            
            category_tok_indices.append((i, j))
            i = j - 1
            category = category.strip()
            category = " ".join(category.split())
            category_list.append(category)
            prefix = ""
            modifier = ""
            category = ""
            is_prev_tok_prep = False
                  
        ## chunk 5: check if token is a prep or not and to extract meaning around preposition
        elif tok.dep_ == 'prep':
            prep_string = ""
            preposition_list.append(tok.text)
            preposition_meaning_list.append(get_preposition_meaning_refined(tok, prep_string))
            is_prev_tok_prep = True
        
        else:
            is_prev_tok_prep = False
        
        i += 1

    category_feature_relation = []
    for cat_index, cat_tuple in enumerate(category_tok_indices):
        quality_set = set()
        for tok_index in range(cat_tuple[0], cat_tuple[1]):
            tok = doc[tok_index]
            for child in tok.children:
                for quality in quality_list:
                    if child.text in quality and quality not in quality_set:
                        category_feature_relation.append(category_list[cat_index] + ":" + quality)
                        quality_set.add(quality)
                        break
            
    
    return quality_list, category_list, preposition_list, preposition_meaning_list, category_feature_relation
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
candidate_sentences['Query'] = candidate_sentences['Query'].fillna('')
quality_tags_list = []
category_tags_list = []
brand_list = []
preposition_list = [] 
preposition_meaning_list = []
category_feature_relation_list = []
# for k in tqdm(prep_df["search_text"]):
for k in tqdm(candidate_sentences["Query"]):
    sentence_split = k.split()
    split_len = len(sentence_split)
    brand_str = ""
    initial_key = ""
    
    for i in range(split_len):
        if sentence_split[i] in data_checker_dict[""]:
            start_index = i
            j = 2
            loop_index = i + 1
            brand_tuple_index = tuple()
            while loop_index <= split_len and " ".join(sentence_split[start_index:loop_index]) in data_checker_dict[" ".join(sentence_split[start_index:(loop_index - 1)])]:
                if " ".join(sentence_split[start_index:loop_index]) in data_checker_set:
                    brand_tuple_index = (start_index, loop_index) 
                j += 1
                loop_index += 1
            if brand_tuple_index:
                brand_str = ' '.join(sentence_split[brand_tuple_index[0]:brand_tuple_index[1]])
                brand_list.append(brand_str)
                print('brand:', brand_str, 'sentence:', k)
                sentence_split[brand_tuple_index[0]:brand_tuple_index[1]] = []
                break
    if not brand_str:
        brand_list.append("")
    k = ' '.join(sentence_split)
    quality_tags, category_tags, preposition_tags, preposition_meaning_tags, category_feature_relation = unsupervised_feature_extraction_dependency_extraction_fashion_augmented(k)
    quality_tags_list.append(quality_tags)
    category_tags_list.append(category_tags)
    preposition_list.append(preposition_tags)
    preposition_meaning_list.append(preposition_meaning_tags)
    category_feature_relation_list.append(category_feature_relation)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
#   0%|          | 0/613 [00:00&lt;?, ?it/s]brand: Fendi sentence: Fendi handbag
# brand: Fendi sentence: Fendi beige handbag
#   1%|          | 7/613 [00:00&lt;00:08, 68.28it/s]brand: FURLA sentence: FURLA pochette
# brand: Coach sentence: Coach work bag
#   2%|▏         | 15/613 [00:00&lt;00:08, 70.09it/s]brand: Burberry sentence: Burberry duffel bag
#   6%|▌         | 38/613 [00:00&lt;00:08, 67.89it/s]brand: Alice sentence: Alice Mccall midi dress
#  10%|█         | 64/613 [00:00&lt;00:07, 75.04it/s]brand: Brandon Maxwell sentence: Brandon Maxwell Blouse
#  13%|█▎        | 81/613 [00:01&lt;00:06, 76.40it/s]brand: Gucci sentence: Gucci sweatshirt
# brand: MARNI sentence: MARNI tube top
#  16%|█▌        | 97/613 [00:01&lt;00:06, 75.67it/s]brand: FRAME sentence: FRAME dark wash jeans
#  18%|█▊        | 113/613 [00:01&lt;00:06, 75.48it/s]brand: Balmain sentence: Balmain shorts
#  20%|█▉        | 121/613 [00:01&lt;00:06, 76.65it/s]brand: Miguelina sentence: Miguelina Shorts
#  23%|██▎       | 138/613 [00:01&lt;00:06, 76.40it/s]brand: Theory sentence: Theory light grey coat
#  28%|██▊       | 170/613 [00:02&lt;00:05, 77.75it/s]brand: Gucci sentence: Gucci watch
#  29%|██▉       | 179/613 [00:02&lt;00:05, 79.21it/s]brand: Calvin Klein sentence: Calvin Klein briefs
# brand: Carine sentence: Carine Gilson bustier
# brand: Paul Smith sentence:  Paul Smith socks
#  34%|███▎      | 206/613 [00:02&lt;00:05, 80.59it/s]brand: Prada sentence: Prada  sunglasses
# brand: Chloe sentence: Chloe wallet
#  35%|███▌      | 215/613 [00:02&lt;00:04, 81.84it/s]brand: Valentino sentence: Valentino pouch
# brand: Gianvito Rossi sentence: Gianvito Rossi boots
#  37%|███▋      | 224/613 [00:02&lt;00:04, 82.56it/s]brand: Jimmy Choo sentence: Jimmy Choo flats
#  38%|███▊      | 233/613 [00:03&lt;00:04, 80.52it/s]brand: Aquazzura sentence: Aquazzura high heels
# brand: Aquazzura sentence: Aquazzura stiletto
# brand: GAIA sentence: CULT GAIA sandals
#  39%|███▉      | 242/613 [00:03&lt;00:04, 79.31it/s]brand: ETRO sentence: men ETRO green polo shirt
# brand: ETRO sentence: men ETRO polo shirt
#  41%|████      | 252/613 [00:03&lt;00:04, 84.78it/s]brand: MARNI sentence: men MARNI solid red sweatshirt
# brand: Dolce &amp; Gabbana sentence: men Dolce &amp; Gabbana green cardigan
#  46%|████▌     | 279/613 [00:03&lt;00:03, 104.32it/s]brand: Jennifer Taylor sentence: Jennifer Taylor tufted sofa
# brand: Jennifer Taylor sentence: Jennifer Taylor tufted camelback sofa
# brand: Jennifer Taylor sentence: Jennifer Taylor tufted camelback sofa cream
#  47%|████▋     | 290/613 [00:03&lt;00:03, 99.86it/s] brand: Armen sentence: Armen Living dining table
# brand: Armen sentence: rustic oak Armen Living dining table
#  49%|████▉     | 301/613 [00:03&lt;00:03, 98.08it/s]brand: Chic sentence:  Home Chic adjustable bar stool
#  60%|██████    | 368/613 [00:04&lt;00:03, 74.48it/s]brand: Alice sentence: Alice Mccall midi dress
#  65%|██████▌   | 400/613 [00:05&lt;00:02, 76.80it/s]brand: Brandon Maxwell sentence: Brandon Maxwell Blouse
#  68%|██████▊   | 416/613 [00:05&lt;00:02, 75.34it/s]brand: Gucci sentence: Gucci sweatshirt
#  69%|██████▉   | 425/613 [00:05&lt;00:02, 77.48it/s]brand: FRAME sentence: FRAME dark wash jeans
#  73%|███████▎  | 450/613 [00:05&lt;00:02, 78.31it/s]brand: Bassike sentence: Bassike shorts
# brand: Miguelina sentence: Miguelina Shorts
#  77%|███████▋  | 475/613 [00:05&lt;00:01, 78.43it/s]brand: Ganni sentence: Ganni bikinis
#  79%|███████▉  | 484/613 [00:06&lt;00:01, 80.12it/s]brand: Zimmermann sentence: Zimmermann Bikinis
#  80%|████████  | 493/613 [00:06&lt;00:01, 80.65it/s]brand: Suzanne sentence: Suzanne Kalan earrings
#  83%|████████▎ | 511/613 [00:06&lt;00:01, 77.78it/s]brand: Pomellato sentence: Pomellato Nudo rings
# brand: Gucci sentence: Gucci watch
# brand: Cartier sentence: Cartier tank watch
#  86%|████████▌ | 528/613 [00:06&lt;00:01, 78.07it/s]brand: Calvin Klein sentence: Calvin Klein briefs
#  88%|████████▊ | 537/613 [00:06&lt;00:00, 79.40it/s]brand: SPANX sentence: SPANX  bodysuit
#  90%|█████████ | 553/613 [00:06&lt;00:00, 75.98it/s]brand: Balenciaga sentence: Balenciaga baseball cap
# brand: Clyde sentence: Clyde sunhat
# brand: Prada sentence: Prada  sunglasses
# brand: Alaia sentence: Alaia acetate sunglasses
#  92%|█████████▏| 562/613 [00:07&lt;00:00, 77.47it/s]brand: Chloe sentence: Chloe wallet
# brand: Valentino sentence: Valentino pouch
#  94%|█████████▍| 578/613 [00:07&lt;00:00, 78.04it/s]brand: Gianvito Rossi sentence: Gianvito Rossi boots
# brand: Jimmy Choo sentence: Jimmy Choo flats
#  97%|█████████▋| 594/613 [00:07&lt;00:00, 75.67it/s]brand: Aquazzura sentence: Aquazzura high heels
# brand: GAIA sentence: CULT GAIA leather sandals
# brand: Chloe sentence: Chloe kids cardigan
# 100%|█████████▉| 610/613 [00:07&lt;00:00, 75.07it/s]brand: Baby sentence: Baby dress
# 100%|██████████| 613/613 [00:07&lt;00:00, 78.98it/s]
# </div>

# %%
qa_tag_extraction_modified = pd.DataFrame(columns=['Query','Brand', 'Quality', 'Category', 'Preposition', 'Preposition Meaning'])
qa_tag_extraction_modified['Query'] = list(candidate_sentences["Query"])
qa_tag_extraction_modified['Brand'] = brand_list
qa_tag_extraction_modified['Quality'] = quality_tags_list
qa_tag_extraction_modified['Category'] = category_tags_list
qa_tag_extraction_modified['Preposition'] = preposition_list
qa_tag_extraction_modified['Preposition Meaning'] = preposition_meaning_list
qa_tag_extraction_modified['Category_Feature_Relation'] = category_feature_relation_list
qa_tag_extraction_modified.to_csv('/dbfs/mnt/nemo/qa_queries_ner_tagger_extraction_with_relation_updated.csv', encoding='utf-8')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
display(qa_tag_extraction_modified)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Query</th><th>Brand</th><th>Quality</th><th>Category</th><th>Preposition</th><th>Preposition Meaning</th><th>Category_Feature_Relation</th></tr></thead><tbody><tr><td>bag</td><td></td><td>List()</td><td>List(bag)</td><td>List()</td><td>List()</td><td>List()</td></tr><tr><td>Fendi handbag</td><td>Fendi</td><td>List()</td><td>List(handbag)</td><td>List()</td><td>List()</td><td>List()</td></tr><tr><td>Fendi beige handbag</td><td>Fendi</td><td>List(beige)</td><td>List(handbag)</td><td>List()</td><td>List()</td><td>List(handbag:beige)</td></tr><tr><td>backpacks</td><td></td><td>List()</td><td>List(backpacks)</td><td>List()</td><td>List()</td><td>List()</td></tr><tr><td>black backpacks</td><td></td><td>List(black)</td><td>List(backpacks)</td><td>List()</td><td>List()</td><td>List(backpacks:black)</td></tr><tr><td>blue bucket bag</td><td></td><td>List(blue)</td><td>List(bucket bag)</td><td>List()</td><td>List()</td><td>List()</td></tr><tr><td>bucketbag</td><td></td><td>List()</td><td>List(bucketbag)</td><td>List()</td><td>List()</td><td>List()</td></tr><tr><td>crocodile print bag</td><td></td><td>List()</td><td>List(crocodile print bag)</td><td>List()</td><td>List()</td><td>List()</td></tr><tr><td>animal print bag</td><td></td><td>List()</td><td>List(animal print bag)</td><td>List()</td><td>List()</td><td>List()</td></tr><tr><td>tote bag</td><td></td><td>List()</td><td>List(bag)</td><td>List()</td><td>List()</td><td>List()</td></tr><tr><td>totes</td><td></td><td>List()</td><td>List(totes)</td><td>List()</td><td>List()</td><td>List()</td></tr><tr><td>FURLA pochette</td><td>FURLA</td><td>List()</td><td>List(pochette)</td><td>List()</td><td>List()</td><td>List()</td></tr><tr><td>red CELINE crossbody </td><td></td><td>List(red)</td><td>List(CELINE crossbody)</td><td>List()</td><td>List()</td><td>List()</td></tr><tr><td>Coach work bag</td><td>Coach</td><td>List()</td><td>List(work bag)</td><td>List()</td><td>List()</td><td>List()</td></tr><tr><td>pink coccinelle bum bag</td><td></td><td>List(pink)</td><td>List(coccinelle bum bag)</td><td>List()</td><td>List()</td><td>List()</td></tr><tr><td>belt bag</td><td></td><td>List()</td><td>List(belt bag)</td><td>List()</td><td>List()</td><td>List()</td></tr><tr><td>Burberry duffel bag</td><td>Burberry</td><td>List(duffel)</td><td>List(bag)</td><td>List()</td><td>List()</td><td>List(bag:duffel)</td></tr><tr><td>faux leather wallet</td><td></td><td>List(faux)</td><td>List(leather wallet)</td><td>List()</td><td>List()</td><td>List()</td></tr><tr><td>pale pink wallet</td><td></td><td>List(pale, pink)</td><td>List(wallet)</td><td>List()</td><td>List()</td><td>List(wallet:pink)</td></tr><tr><td>Floral print midi dress</td><td></td><td>List(Floral)</td><td>List(print midi dress)</td><td>List()</td><td>List()</td><td>List()</td></tr><tr><td>red sheath dress</td><td></td><td>List(red, sheath)</td><td>List(dress)</td><td>List()</td><td>List()</td><td>List(dress:red, dress:sheath)</td></tr><tr><td>little black dress</td><td></td><td>List(little, black)</td><td>List(dress)</td><td>List()</td><td>List()</td><td>List(dress:little, dress:black)</td></tr><tr><td>yellow short sleeve mini dress</td><td></td><td>List(yellow, short, sleeve, mini)</td><td>List(dress)</td><td>List()</td><td>List()</td><td>List(dress:yellow, dress:sleeve, dress:mini)</td></tr><tr><td>burgundy crewneck dress</td><td></td><td>List()</td><td>List(burgundy crewneck dress)</td><td>List()</td><td>List()</td><td>List()</td></tr><tr><td>crew neck dress</td><td></td><td>List()</td><td>List(crew neck dress)</td><td>List()</td><td>List()</td><td>List()</td></tr><tr><td>Off Shoulder Dress</td><td></td><td>List()</td><td>List(Shoulder Dress)</td><td>List()</td><td>List()</td><td>List()</td></tr><tr><td>A line dress</td><td></td><td>List()</td><td>List(line dress)</td><td>List()</td><td>List()</td><td>List()</td></tr><tr><td>animal p ...
