# %%
import pandas as pd

df1 = pd.read_csv("/dbfs/FileStore/shared_uploads/t_karthik.ragunath@tatadigital.com/Demo_Regression_SearchTypes.csv", header=0)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df1.columns
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[2]: Index([&#39;Unnamed: 0&#39;, &#39;Query&#39;, &#39;Preposition&#39;, &#39;Preposition Meaning&#39;, &#39;Brand&#39;,
#        &#39;Autotags&#39;, &#39;Quality&#39;, &#39;Category&#39;, &#39;Category_Feature_Relation&#39;,
#        &#39;Old Tagger&#39;, &#39;Is New Tagger Not Ideal?&#39;, &#39;Search Query Type&#39;],
#       dtype=&#39;object&#39;)</div>

# %%
df_n = df1[df1['Search Query Type'] == 'Natural Language Search']
df_p = df1[df1['Search Query Type'] == 'Product Search']
df_f = df1[~df1['Search Query Type'].isin(['Product Search', 'Natural Language Search'])]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df_n.to_csv('/dbfs/mnt/nemo/natural_langauge_search.csv', encoding='utf-8')
df_p.to_csv('/dbfs/mnt/nemo/product_search.csv', encoding='utf-8')
df_f.to_csv('/dbfs/mnt/nemo/feature_search.csv', encoding='utf-8')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
